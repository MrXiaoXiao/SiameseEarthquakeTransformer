# %%
import numpy as np
from pathlib import Path
import pandas as pd
import h5py
import matplotlib.pyplot as plt
import obspy
import bisect
from pyproj import Geod
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '3'
import sys
sys.path.append('/home/Public/SiameseEQTransformer/SiameseEQT/')
from src.S_EqT_model import S_EqT_Model_create
from src.S_EqT_model import S_EqT_Model_seprate
from src.S_EqT_model import S_EqT_RSRN_Model
from src.S_EqT_model import S_EqT_HED_Model
from src.S_EqT_concate_fix_corr import S_EqT_Concate_RSRN_Model
from src.misc import get_train_list
import keras.backend
import yaml
from random import shuffle

# %% [markdown]
# # Load model

# %%
keras.backend.set_floatx('float32')
# load configuration files
cfgs = yaml.load(open('S_Test_example.yaml','r'),Loader=yaml.BaseLoader)
if_encoder_concate = int(cfgs['Model']['Encoder_concate'])
if if_encoder_concate == 1:
    encode_model, siamese_model, EqT_model = S_EqT_Concate_RSRN_Model(cfgs)
    encoder_encoded_list = cfgs['Model']['Encoder_concate_list']
    encoder_encoded_lengths = cfgs['Model']['Encoder_concate_lengths']
    encoder_encoded_channels = cfgs['Model']['Encoder_concate_channels']
        
elif int(cfgs['Model']['MODEL_RSRN'] == 0):
    encode_model, siamese_model, EqT_model = S_EqT_HED_Model(cfgs)
else:
    encode_model, siamese_model, EqT_model = S_EqT_RSRN_Model(cfgs)

if int(cfgs['Model']['LoadPretrainedModel']) == 1:
    siamese_model.load_weights(cfgs['Model']['PretrainModelPath'])
# Out:
# Start loading EqT model...
# WARNING:tensorflow:From /root/anaconda3/envs/eqt/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /root/anaconda3/envs/eqt/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Start building EqT encoder model...
# Start building Siamese EqT model...
# Start building correlation layers...
# Start sideoutput & residual layers...
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 6000, 3)      0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 6000, 8)      272         input[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 3000, 8)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 3000, 16)     1168        max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 1500, 16)     0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 1500, 16)     1808        max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 750, 16)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 750, 32)      3616        max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 375, 32)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 375, 32)      5152        max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 188, 32)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 188, 64)      10304       max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 94, 64)       0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 94, 64)       12352       max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 47, 64)       0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 47, 64)       256         max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 47, 64)       0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_1 (SpatialDro (None, 47, 64)       0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 47, 64)       12352       spatial_dropout1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 47, 64)       256         conv1d_8[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 47, 64)       0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_2 (SpatialDro (None, 47, 64)       0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 47, 64)       12352       spatial_dropout1d_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 47, 64)       0           max_pooling1d_7[0][0]
#                                                                  conv1d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 47, 64)       256         add_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 47, 64)       0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_3 (SpatialDro (None, 47, 64)       0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 47, 64)       12352       spatial_dropout1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 47, 64)       256         conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 47, 64)       0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_4 (SpatialDro (None, 47, 64)       0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 47, 64)       12352       spatial_dropout1d_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 47, 64)       0           add_1[0][0]
#                                                                  conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 47, 64)       256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 47, 64)       0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_5 (SpatialDro (None, 47, 64)       0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 47, 64)       12352       spatial_dropout1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 47, 64)       256         conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 47, 64)       0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_6 (SpatialDro (None, 47, 64)       0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 47, 64)       12352       spatial_dropout1d_6[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 47, 64)       0           add_2[0][0]
#                                                                  conv1d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 47, 64)       256         add_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 47, 64)       0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_7 (SpatialDro (None, 47, 64)       0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 47, 64)       12352       spatial_dropout1d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 47, 64)       256         conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 47, 64)       0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_8 (SpatialDro (None, 47, 64)       0           activation_8[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 47, 64)       12352       spatial_dropout1d_8[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 47, 64)       0           add_3[0][0]
#                                                                  conv1d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 47, 64)       256         add_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 47, 64)       0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_9 (SpatialDro (None, 47, 64)       0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 47, 64)       8256        spatial_dropout1d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 47, 64)       256         conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 47, 64)       0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_10 (SpatialDr (None, 47, 64)       0           activation_10[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 47, 64)       8256        spatial_dropout1d_10[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 47, 64)       0           add_4[0][0]
#                                                                  conv1d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 47, 64)       256         add_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 47, 64)       0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_11 (SpatialDr (None, 47, 64)       0           activation_11[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 47, 64)       12352       spatial_dropout1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 47, 64)       256         conv1d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 47, 64)       0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_12 (SpatialDr (None, 47, 64)       0           activation_12[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 47, 64)       12352       spatial_dropout1d_12[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 47, 64)       0           add_5[0][0]
#                                                                  conv1d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 47, 64)       256         add_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 47, 64)       0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_13 (SpatialDr (None, 47, 64)       0           activation_13[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 47, 64)       8256        spatial_dropout1d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 47, 64)       256         conv1d_20[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 47, 64)       0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_14 (SpatialDr (None, 47, 64)       0           activation_14[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 47, 64)       8256        spatial_dropout1d_14[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 47, 64)       0           add_6[0][0]
#                                                                  conv1d_21[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 47, 32)       10368       add_7[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 47, 16)       528         bidirectional_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 47, 16)       64          conv1d_22[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 47, 32)       4224        batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 47, 16)       528         bidirectional_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 47, 16)       64          conv1d_23[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 47, 32)       4224        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 47, 16)       528         bidirectional_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 47, 16)       64          conv1d_24[0][0]
# __________________________________________________________________________________________________
# attentionD0 (SeqSelfAttention)  [(None, 47, 16), (No 1089        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 47, 16)       0           batch_normalization_17[0][0]
#                                                                  attentionD0[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 47, 16)       32          add_8[0][0]
# __________________________________________________________________________________________________
# feed_forward_1 (FeedForward)    (None, 47, 16)       4240        layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 47, 16)       0           layer_normalization_1[0][0]
#                                                                  feed_forward_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 47, 16)       32          add_9[0][0]
# __________________________________________________________________________________________________
# attentionD (SeqSelfAttention)   [(None, 47, 16), (No 1089        layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 47, 16)       0           layer_normalization_2[0][0]
#                                                                  attentionD[0][0]
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 47, 16)       32          add_10[0][0]
# __________________________________________________________________________________________________
# feed_forward_2 (FeedForward)    (None, 47, 16)       4240        layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 47, 16)       0           layer_normalization_3[0][0]
#                                                                  feed_forward_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_4 (LayerNor (None, 47, 16)       32          add_11[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 47, 16)       2112        layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# attentionS (SeqSelfAttention)   [(None, 47, 16), (No 1089        lstm_5[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_15 (UpSampling1D) (None, 94, 16)       0           attentionS[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 94, 64)       3136        up_sampling1d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_16 (UpSampling1D) (None, 188, 64)      0           conv1d_39[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 188, 64)      20544       up_sampling1d_16[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_17 (UpSampling1D) (None, 376, 64)      0           conv1d_40[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 376, 32)      10272       up_sampling1d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_18 (UpSampling1D) (None, 752, 32)      0           conv1d_41[0][0]
# __________________________________________________________________________________________________
# cropping1d_3 (Cropping1D)       (None, 750, 32)      0           up_sampling1d_18[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 750, 32)      7200        cropping1d_3[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_19 (UpSampling1D) (None, 1500, 32)     0           conv1d_42[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 1500, 16)     3600        up_sampling1d_19[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_20 (UpSampling1D) (None, 3000, 16)     0           conv1d_43[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, 3000, 16)     2320        up_sampling1d_20[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_21 (UpSampling1D) (None, 6000, 16)     0           conv1d_44[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 6000, 8)      1416        up_sampling1d_21[0][0]
# ==================================================================================================
# Total params: 277,867
# Trainable params: 275,979
# Non-trainable params: 1,888
# __________________________________________________________________________________________________
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# batch_normalization_17_Template (None, None, 1, 16)  0
# __________________________________________________________________________________________________
# batch_normalization_17_Search ( (None, 47, 1, 16)    0
# __________________________________________________________________________________________________
# batch_normalization_16_Template (None, None, 1, 16)  0
# __________________________________________________________________________________________________
# batch_normalization_16_Search ( (None, 47, 1, 16)    0
# __________________________________________________________________________________________________
# batch_normalization_15_Template (None, None, 1, 16)  0
# __________________________________________________________________________________________________
# batch_normalization_15_Search ( (None, 47, 1, 16)    0
# __________________________________________________________________________________________________
# batch_normalization_14_Template (None, None, 1, 64)  0
# __________________________________________________________________________________________________
# batch_normalization_14_Search ( (None, 47, 1, 64)    0
# __________________________________________________________________________________________________
# batch_normalization_12_Template (None, None, 1, 64)  0
# __________________________________________________________________________________________________
# batch_normalization_12_Search ( (None, 47, 1, 64)    0
# __________________________________________________________________________________________________
# batch_normalization_10_Template (None, None, 1, 64)  0
# __________________________________________________________________________________________________
# batch_normalization_10_Search ( (None, 47, 1, 64)    0
# __________________________________________________________________________________________________
# batch_normalization_8_Template  (None, None, 1, 64)  0
# __________________________________________________________________________________________________
# batch_normalization_8_Search (I (None, 47, 1, 64)    0
# __________________________________________________________________________________________________
# batch_normalization_6_Template  (None, None, 1, 64)  0
# __________________________________________________________________________________________________
# batch_normalization_6_Search (I (None, 47, 1, 64)    0
# __________________________________________________________________________________________________
# batch_normalization_4_Template  (None, None, 1, 64)  0
# __________________________________________________________________________________________________
# batch_normalization_4_Search (I (None, 47, 1, 64)    0
# __________________________________________________________________________________________________
# batch_normalization_2_Template  (None, None, 1, 64)  0
# __________________________________________________________________________________________________
# batch_normalization_2_Search (I (None, 47, 1, 64)    0
# __________________________________________________________________________________________________
# batch_normalization_17_corr (La (None, 47, 1, 16)    0           batch_normalization_17_Template[0
#                                                                  batch_normalization_17_Search[0][
# __________________________________________________________________________________________________
# batch_normalization_16_corr (La (None, 47, 1, 16)    0           batch_normalization_16_Template[0
#                                                                  batch_normalization_16_Search[0][
# __________________________________________________________________________________________________
# batch_normalization_15_corr (La (None, 47, 1, 16)    0           batch_normalization_15_Template[0
#                                                                  batch_normalization_15_Search[0][
# __________________________________________________________________________________________________
# batch_normalization_14_corr (La (None, 47, 1, 64)    0           batch_normalization_14_Template[0
#                                                                  batch_normalization_14_Search[0][
# __________________________________________________________________________________________________
# batch_normalization_12_corr (La (None, 47, 1, 64)    0           batch_normalization_12_Template[0
#                                                                  batch_normalization_12_Search[0][
# __________________________________________________________________________________________________
# batch_normalization_10_corr (La (None, 47, 1, 64)    0           batch_normalization_10_Template[0
#                                                                  batch_normalization_10_Search[0][
# __________________________________________________________________________________________________
# batch_normalization_8_corr (Lam (None, 47, 1, 64)    0           batch_normalization_8_Template[0]
#                                                                  batch_normalization_8_Search[0][0
# __________________________________________________________________________________________________
# batch_normalization_6_corr (Lam (None, 47, 1, 64)    0           batch_normalization_6_Template[0]
#                                                                  batch_normalization_6_Search[0][0
# __________________________________________________________________________________________________
# batch_normalization_4_corr (Lam (None, 47, 1, 64)    0           batch_normalization_4_Template[0]
#                                                                  batch_normalization_4_Search[0][0
# __________________________________________________________________________________________________
# batch_normalization_2_corr (Lam (None, 47, 1, 64)    0           batch_normalization_2_Template[0]
#                                                                  batch_normalization_2_Search[0][0
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 47, 1, 32)    0           batch_normalization_17_corr[0][0]
#                                                                  batch_normalization_17_Search[0][
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 47, 1, 32)    0           batch_normalization_16_corr[0][0]
#                                                                  batch_normalization_16_Search[0][
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 47, 1, 32)    0           batch_normalization_15_corr[0][0]
#                                                                  batch_normalization_15_Search[0][
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 47, 1, 128)   0           batch_normalization_14_corr[0][0]
#                                                                  batch_normalization_14_Search[0][
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 47, 1, 128)   0           batch_normalization_12_corr[0][0]
#                                                                  batch_normalization_12_Search[0][
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 47, 1, 128)   0           batch_normalization_10_corr[0][0]
#                                                                  batch_normalization_10_Search[0][
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 47, 1, 128)   0           batch_normalization_8_corr[0][0]
#                                                                  batch_normalization_8_Search[0][0
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 47, 1, 128)   0           batch_normalization_6_corr[0][0]
#                                                                  batch_normalization_6_Search[0][0
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 47, 1, 128)   0           batch_normalization_4_corr[0][0]
#                                                                  batch_normalization_4_Search[0][0
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 47, 1, 128)   0           batch_normalization_2_corr[0][0]
#                                                                  batch_normalization_2_Search[0][0
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 47, 1, 992)   0           concatenate_8[0][0]
#                                                                  concatenate_9[0][0]
#                                                                  concatenate_10[0][0]
#                                                                  concatenate_11[0][0]
#                                                                  concatenate_12[0][0]
#                                                                  concatenate_13[0][0]
#                                                                  concatenate_14[0][0]
#                                                                  concatenate_15[0][0]
#                                                                  concatenate_16[0][0]
#                                                                  concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 47, 1, 512)   1524224     concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 47, 1, 256)   393472      conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 47, 1, 128)   98432       conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_39_Template (InputLayer) (None, None, 1, 64)  0
# __________________________________________________________________________________________________
# conv1d_39_Search (InputLayer)   (None, 94, 1, 64)    0
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 94, 1, 128)   32896       conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_39_corr (Lambda)         (None, 94, 1, 64)    0           conv1d_39_Template[0][0]
#                                                                  conv1d_39_Search[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 94, 1, 64)    24640       conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 94, 1, 128)   0           conv1d_39_corr[0][0]
#                                                                  conv1d_39_Search[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 94, 1, 64)    12352       conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 94, 1, 192)   0           concatenate_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_40_Template (InputLayer) (None, None, 1, 64)  0
# __________________________________________________________________________________________________
# conv1d_40_Search (InputLayer)   (None, 188, 1, 64)   0
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 94, 1, 32)    18464       concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv1d_40_corr (Lambda)         (None, 188, 1, 64)   0           conv1d_40_Template[0][0]
#                                                                  conv1d_40_Search[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 94, 1, 32)    3104        conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 188, 1, 128)  0           conv1d_40_corr[0][0]
#                                                                  conv1d_40_Search[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 94, 1, 32)    3104        conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 188, 1, 32)   12320       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 94, 1, 16)    528         conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 188, 1, 32)   3104        conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_41_Template (InputLayer) (None, None, 1, 32)  0
# __________________________________________________________________________________________________
# conv1d_41_Search (InputLayer)   (None, 376, 1, 32)   0
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 188, 1, 32)   3104        conv2d_11[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 94, 1, 8)     0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv1d_41_corr (Lambda)         (None, 376, 1, 32)   0           conv1d_41_Template[0][0]
#                                                                  conv1d_41_Search[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 188, 1, 16)   528         conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 188, 1, 8)    200         lambda_1[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 376, 1, 64)   0           conv1d_41_corr[0][0]
#                                                                  conv1d_41_Search[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 188, 1, 24)   0           conv2d_13[0][0]
#                                                                  conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 376, 1, 32)   6176        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 188, 1, 16)   400         concatenate_20[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 376, 1, 32)   3104        conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 376, 1, 32)   3104        conv2d_16[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 188, 1, 8)    0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv1d_42_Template (InputLayer) (None, None, 1, 32)  0
# __________________________________________________________________________________________________
# conv1d_42_Search (InputLayer)   (None, 750, 1, 32)   0
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 376, 1, 16)   528         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 376, 1, 8)    200         lambda_3[0][0]
# __________________________________________________________________________________________________
# conv1d_42_corr (Lambda)         (None, 750, 1, 32)   0           conv1d_42_Template[0][0]
#                                                                  conv1d_42_Search[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 376, 1, 24)   0           conv2d_18[0][0]
#                                                                  conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 750, 1, 64)   0           conv1d_42_corr[0][0]
#                                                                  conv1d_42_Search[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 376, 1, 16)   400         concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 750, 1, 32)   6176        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 750, 1, 32)   3104        conv2d_20[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 376, 1, 8)    0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv1d_43_Template (InputLayer) (None, None, 1, 16)  0
# __________________________________________________________________________________________________
# conv1d_43_Search (InputLayer)   (None, 1500, 1, 16)  0
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 750, 1, 32)   3104        conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 752, 1, 8)    200         lambda_5[0][0]
# __________________________________________________________________________________________________
# conv1d_43_corr (Lambda)         (None, 1500, 1, 16)  0           conv1d_43_Template[0][0]
#                                                                  conv1d_43_Search[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 750, 1, 16)   528         conv2d_22[0][0]
# __________________________________________________________________________________________________
# cropping2d_4 (Cropping2D)       (None, 750, 1, 8)    0           conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 1500, 1, 32)  0           conv1d_43_corr[0][0]
#                                                                  conv1d_43_Search[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 750, 1, 24)   0           conv2d_23[0][0]
#                                                                  cropping2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 1500, 1, 32)  3104        concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 750, 1, 16)   400         concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 1500, 1, 32)  3104        conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv1d_44_Template (InputLayer) (None, None, 1, 16)  0
# __________________________________________________________________________________________________
# conv1d_44_Search (InputLayer)   (None, 3000, 1, 16)  0
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 1500, 1, 32)  3104        conv2d_26[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 750, 1, 8)    0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_44_corr (Lambda)         (None, 3000, 1, 16)  0           conv1d_44_Template[0][0]
#                                                                  conv1d_44_Search[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 1500, 1, 16)  528         conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 1500, 1, 8)   200         lambda_7[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 3000, 1, 32)  0           conv1d_44_corr[0][0]
#                                                                  conv1d_44_Search[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 1500, 1, 24)  0           conv2d_28[0][0]
#                                                                  conv2d_transpose_9[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 3000, 1, 32)  3104        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 1500, 1, 16)  400         concatenate_23[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 3000, 1, 32)  3104        conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv1d_45_Template (InputLayer) (None, None, 1, 8)   0
# __________________________________________________________________________________________________
# conv1d_45_Search (InputLayer)   (None, 6000, 1, 8)   0
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 3000, 1, 32)  3104        conv2d_31[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 1500, 1, 8)   0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv1d_45_corr (Lambda)         (None, 6000, 1, 8)   0           conv1d_45_Template[0][0]
#                                                                  conv1d_45_Search[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 3000, 1, 16)  528         conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 3000, 1, 8)   200         lambda_9[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 6000, 1, 16)  0           conv1d_45_corr[0][0]
#                                                                  conv1d_45_Search[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 3000, 1, 24)  0           conv2d_33[0][0]
#                                                                  conv2d_transpose_11[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 6000, 1, 32)  1568        concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 3000, 1, 16)  400         concatenate_24[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 6000, 1, 32)  3104        conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 6000, 1, 32)  3104        conv2d_36[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 3000, 1, 8)   0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 6000, 1, 16)  528         conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_13 (Conv2DTran (None, 6000, 1, 8)   200         lambda_11[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 94, 1, 8)     0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 188, 1, 16)   0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 376, 1, 16)   0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 6000, 1, 24)  0           conv2d_38[0][0]
#                                                                  conv2d_transpose_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 6016, 1, 1)   9           lambda_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 6016, 1, 1)   17          lambda_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 6016, 1, 1)   17          lambda_6[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 750, 1, 16)   0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 1500, 1, 16)  0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 3000, 1, 16)  0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 6000, 1, 8)   200         concatenate_25[0][0]
# __________________________________________________________________________________________________
# cropping2d_1 (Cropping2D)       (None, 6000, 1, 1)   0           conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# cropping2d_2 (Cropping2D)       (None, 6000, 1, 1)   0           conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# cropping2d_3 (Cropping2D)       (None, 6000, 1, 1)   0           conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 6000, 1, 1)   17          lambda_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 6000, 1, 1)   17          lambda_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 6000, 1, 1)   17          lambda_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_14 (Conv2DTran (None, 6000, 1, 1)   9           conv2d_39[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 6000, 1, 7)   0           cropping2d_1[0][0]
#                                                                  cropping2d_2[0][0]
#                                                                  cropping2d_3[0][0]
#                                                                  conv2d_transpose_8[0][0]
#                                                                  conv2d_transpose_10[0][0]
#                                                                  conv2d_transpose_12[0][0]
#                                                                  conv2d_transpose_14[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 6000, 1, 1)   0           cropping2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 6000, 1, 1)   0           cropping2d_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 6000, 1, 1)   0           cropping2d_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 6000, 1, 1)   0           conv2d_transpose_8[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 6000, 1, 1)   0           conv2d_transpose_10[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 6000, 1, 1)   0           conv2d_transpose_12[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 6000, 1, 1)   0           conv2d_transpose_14[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 6000, 1, 1)   8           concatenate_26[0][0]
# ==================================================================================================
# Total params: 2,187,591
# Trainable params: 2,187,591
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
siamese_model.load_weights('/home/Public/SiameseEQTransformer/SiameseEQT/models/S_Add_Noise_1023_UNI_NEW_model330000.hdf5')

# %%
# For P or S
# difference is velocity and trained model and encoded model
# set up model
base_time = obspy.UTCDateTime(2010,1,1)
# search params
# search distance in km
max_search_distance = 30
# template P threshold 0.5
template_P_min_threshold = 0.5
template_S_min_threshold = 0.5

VpRefMin = 3.5
VsRefMin = 2.5

P_boundary_time = 1.0
S_boundary_time = 1.0

sta_list_file_path = '/mnt/BYEB/LA_JAN/LA_DATA/PostProcess/LAN_REAL_Use.dat'
prev_file_str = '/mnt/BYEB/LA_JAN/LA_DATA/PostProcess/EQTRes/20100101/'
search_hdf5_prefix =  '/mnt/BYEB/LA_JAN/LA_DATA/LA_2010_Jan_processed_hdfs/'
detections_prefix = '/mnt/BYEB/LA_JAN/LA_DATA/LA_2010_Jan_detections/'

# %%
GEOD = Geod(ellps='WGS84')
# Rough meters/degree calculation
M_PER_DEG = (GEOD.inv(0, 0, 0, 1)[2] + GEOD.inv(0, 0, 1, 0)[2]) / 2

# %%
def get_search_station_list(station, station_list, max_distance):
    search_list = list()
    for t_sta in station_list:
        # skip self
        if t_sta[0] == station[0]:
            continue
        # calculate distance
        t_dis = GEOD.inv(t_sta[3],t_sta[2],station[3],station[2])[2]/1000.0
        if t_dis > max_distance:
            continue
        search_list.append(t_sta)
    return search_list

# %%
station_list = list()
s_eqt_dict = dict()
station_list_file = open(sta_list_file_path,'r')
sta_id = 0
for line in station_list_file.readlines():
    if len(line) < 3:
        continue
    splits = line.split(' ')
    sta_name = splits[2]+'.'+splits[3]
    
    s_eqt_dict[sta_name] = dict()
    s_eqt_dict[sta_name]['P'] = list()
    s_eqt_dict[sta_name]['S'] = list()
    s_eqt_dict[sta_name]['P_Prob'] = list()
    s_eqt_dict[sta_name]['S_Prob'] = list()
    
    sta_lat = float(splits[1])
    sta_lon = float(splits[0])
    
    station_list.append( (sta_id, sta_name, sta_lat, sta_lon) )
    sta_id += 1

# %%
keep_t = None
for sta_key in s_eqt_dict.keys():
    S_EqT_P_list = list()
    #print(sta_key)

    s_times = list()
    s_probs = list()
    
    prev_file = prev_file_str + '{}.S.txt'.format(sta_key)
    if os.path.exists(prev_file):
        f = open(prev_file,'r')
        for line in f.readlines():
            if len(line) > 3:
                s_times.append(float(line.split(' ')[0]))
                s_probs.append(float(line.split(' ')[1]))
        f.close()
    else:
        print(prev_file)
    #print(indexs)
    #s_times = s_times[indexs]
    #s_probs = s_probs[indexs]
    s_eqt_dict[sta_key]['S'] = s_times
    s_eqt_dict[sta_key]['S_Prob'] = s_probs

# %%
train_E_num = int(cfgs['Train']['Train_E_num'])
train_set_path = cfgs['Train']['Train_data_path']
step_num = 0

print_interval = int(cfgs['Train']['Train_print_interval'])
save_interval = int(cfgs['Train']['Model_save_interval'])
save_path = cfgs['Train']['Model_save_path']

RSRN_lengths = cfgs['Model']['RSRN_Encoded_lengths']
RSRN_channels = cfgs['Model']['RSRN_Encoded_channels']

# %%
len(s_eqt_dict['CI.RIN']['S'])
# Out:
# 10

# %%
plot_dx = 0
sta_search_dx = 0
plot_num = 0
for sta in station_list:
    sta_search_dx += 1
    print('On {} of {}'.format(sta_search_dx, len(station_list)))
    # select stations to search
    h5py_base_dir = search_hdf5_prefix
    search_list = get_search_station_list(sta, station_list, max_search_distance)
    seed_csv = detections_prefix + '{}_outputs/X_prediction_results.csv'.format(sta[1][3:])
    seed_csv_file = pd.read_csv(seed_csv)
    for e_time in seed_csv_file['file_name']:
        mask = (seed_csv_file['file_name'] == e_time)
        try:
            spt_t = obspy.UTCDateTime(seed_csv_file[mask]['p_arrival_time'].values[0]) - obspy.UTCDateTime(e_time[-27:])
            sst_t = obspy.UTCDateTime(seed_csv_file[mask]['s_arrival_time'].values[0]) - obspy.UTCDateTime(e_time[-27:])
            spt_prob = seed_csv_file[mask]['p_probability'].values[0]
            sst_prob = seed_csv_file[mask]['s_probability'].values[0]
        except:
            continue
        if sst_prob < 0.3:
            print('No GOOD SKIP')
            continue
        else:
            print('COOL Go ahead')
        spt = np.zeros([1,1])
        spt[0,0] = float(spt_t/60.0)
        sst = np.zeros([1,1])
        sst[0,0] = float(sst_t/60.0)
        coda_end = np.zeros([1,1])
        coda_end[0,0] = float(sst_t/60.0)
        print(e_time)
        ref_pick_time = obspy.UTCDateTime(e_time[-27:]) + spt[0,0] * 60 - base_time
        print('REF TIME:{}'.format(ref_pick_time))
        seed_h5file = h5py_base_dir + '{}.hdf5'.format(sta[1][3:])
        with h5py.File(seed_h5file,'r') as f:
            dataset = f.get('data/'+e_time)
            data_t = np.array(dataset)
            data_t -= np.mean(data_t, axis=0 ,keepdims=True)
            t_std = np.std(data_t, axis = 0, keepdims=True)
            t_std[t_std == 0] = 1.0
            data_t /= t_std
            data_t -= np.mean(data_t, axis=0 ,keepdims=True)
            data_t_in = np.zeros([1,6000,3])
            data_t_in[0,:,:] = data_t
            
        for search_sta in search_list:
            # check if pick exists 
            #print(search_sta)
            search_ref_picks = s_eqt_dict[search_sta[1]]['S'] 
            if len(search_ref_picks) > 1:
                ref_key_id = bisect.bisect_left(search_ref_picks,ref_pick_time)
                try:
                    ref_left = np.abs(search_ref_picks[ref_key_id-1] - ref_pick_time)
                    ref_middle = np.abs(search_ref_picks[ref_key_id] - ref_pick_time)
                    ref_right = np.abs(search_ref_picks[ref_key_id+1] - ref_pick_time)
                    if ref_left < 60.0 or ref_middle < 60.0 or ref_right < 60.0:
                        print('Skipping {}'.format(search_sta[1]))
                        continue
                except:
                    pass
            else:
                pass
            h5py_base_dir_search = search_hdf5_prefix
            search_csvfile = h5py_base_dir_search + '{}.csv'.format(search_sta[1][3:])
            search_csvfile = pd.read_csv(search_csvfile)            
            keys = list(search_csvfile['trace_name'])
            if len(keys) < 2:
                print('Keys Error')
                continue
            prefix = keys[0][:-27]
            keys = [key[-27:] for key in keys]
            key_id = bisect.bisect_left(keys,e_time[-27:])
            
            try:
                search_keys = [keys[key_id-2],keys[key_id-1],keys[key_id],keys[key_id+1],keys[key_id+2]]
            except:
                print('Search_keys Error')
                continue
            # calculate key search range

            search_h5file =  h5py_base_dir_search + '{}.hdf5'.format(search_sta[1][3:])
            t_update_list = list()
            t_update_list_prob = list()
            with h5py.File(search_h5file,'r') as f:
                max_pred_amp = 0
                for search_key in search_keys:

                    t_search_key = prefix + search_key
                    dataset = f.get('data/'+t_search_key)
                    data_s = np.array(dataset)
                    data_s -= np.mean(data_s, axis=0 ,keepdims=True)
                    t_std = np.std(data_s, axis = 0, keepdims=True)
                    t_std[t_std == 0] = 1.0
                    data_s /= t_std

                    data_s_in = np.zeros([1,6000,3])
                    data_s_in[0,:,:] = data_s

                    encoded_t = encode_model.predict(data_t_in)
                    encoded_s = encode_model.predict(data_s_in)

                    siamese_input_list = list()

                    for rdx in range(len(RSRN_lengths)):
                        temp_length = float(RSRN_lengths[rdx])
                        template_s = int(spt[0,0]*temp_length) - 1
                        template_e = int(coda_end[0,0]*temp_length) + 1
                        template_w = int(template_e - template_s)
                        encoded_t[rdx] = encoded_t[rdx][:,template_s:template_e,:]/float(template_w)
                        encoded_t[rdx] = encoded_t[rdx].reshape([1,template_w,1,int(RSRN_channels[rdx])])
                        encoded_s[rdx] = encoded_s[rdx].reshape([1,int(RSRN_lengths[rdx]),1,int(RSRN_channels[rdx])])

                        # channel normalization
                        for channel_dx in range(int(RSRN_channels[rdx])):
                            encoded_s[rdx][0,:,0,channel_dx] -= np.max(encoded_s[rdx][0,:,0,channel_dx])
                            half_window_len = int( 200.0*temp_length/6000.0   ) + 1
                            #window_mean = np.mean(encoded_s[rdx][0,half_window_len:-half_window_len,0,channel_dx])

                            encoded_s[rdx][0,:half_window_len,0,channel_dx] = encoded_s[rdx][0,half_window_len,0,channel_dx]
                            encoded_s[rdx][0,-half_window_len:,0,channel_dx] =  encoded_s[rdx][0,-half_window_len,0,channel_dx]

                            encoded_s[rdx][0,:,0,channel_dx] *= -1.0
                            encoded_s[rdx][0,:,0,channel_dx] -= np.mean(encoded_s[rdx][0,:,0,channel_dx])
                            t_max = np.max(np.abs(encoded_s[rdx][0,:,0,channel_dx]))
                            if t_max < 0.01:
                                t_max = 1
                            encoded_s[rdx][0,:,0,channel_dx] /= t_max

                            encoded_t[rdx][0,:,0,channel_dx] -= np.max(encoded_t[rdx][0,:,0,channel_dx])
                            encoded_t[rdx][0,:,0,channel_dx] *= -1.0
                            encoded_t[rdx][0,:,0,channel_dx] -= np.mean(encoded_t[rdx][0,:,0,channel_dx])
                            t_max = np.max(np.abs(encoded_t[rdx][0,:,0,channel_dx]))
                            if t_max < 0.01:
                                t_max = 1
                            encoded_t[rdx][0,:,0,channel_dx] /= t_max

                        siamese_input_list.append(encoded_t[rdx])
                        siamese_input_list.append(encoded_s[rdx])

                    #print('RSRN Channel_normal OK')
                    if if_encoder_concate == 1:
                        for rdx in range(len(RSRN_lengths), len(RSRN_lengths) + len(encoder_encoded_list)):
                            rdx_2 = rdx - len(RSRN_lengths) 
                            temp_length = float(encoder_encoded_lengths[rdx_2])
                            template_s = int(spt[0,0]*temp_length) - 1
                            template_e = int(coda_end[0,0]*temp_length) + 1
                            template_w = int(template_e - template_s)
                            #print('Concate 1 OK')
                            encoded_t[rdx] = encoded_t[rdx][:,template_s:template_e,:]/float(template_w)
                            encoded_t[rdx] = encoded_t[rdx].reshape([1,template_w,1,int(encoder_encoded_channels[rdx_2])])
                            encoded_s[rdx] = encoded_s[rdx].reshape([1,int(encoder_encoded_lengths[rdx_2]),1,int(encoder_encoded_channels[rdx_2])])
                            #print('Concate 2 OK')
                            # channel normalization
                            for channel_dx in range(int(encoder_encoded_channels[rdx_2])):
                                encoded_s[rdx][0,:,0,channel_dx] -= np.max(encoded_s[rdx][0,:,0,channel_dx])
                                half_window_len = int( 200.0*temp_length/6000.0   ) + 1
                                #window_mean = np.mean(encoded_s[rdx][0,half_window_len:-half_window_len,0,channel_dx])
                                #print('Concate 3 OK')
                                encoded_s[rdx][0,:half_window_len,0,channel_dx] = encoded_s[rdx][0,half_window_len,0,channel_dx]
                                encoded_s[rdx][0,-half_window_len:,0,channel_dx] =  encoded_s[rdx][0,-half_window_len,0,channel_dx]
                                #print('Concate 4 OK')
                                encoded_s[rdx][0,:,0,channel_dx] *= -1.0
                                encoded_s[rdx][0,:,0,channel_dx] -= np.mean(encoded_s[rdx][0,:,0,channel_dx])
                                t_max = np.max(np.abs(encoded_s[rdx][0,:,0,channel_dx]))
                                if t_max < 0.01:
                                    t_max = 1
                                encoded_s[rdx][0,:,0,channel_dx] /= t_max
                                #print('Concate 5 OK')
                                encoded_t[rdx][0,:,0,channel_dx] -= np.max(encoded_t[rdx][0,:,0,channel_dx])
                                encoded_t[rdx][0,:,0,channel_dx] *= -1.0
                                encoded_t[rdx][0,:,0,channel_dx] -= np.mean(encoded_t[rdx][0,:,0,channel_dx])
                                t_max = np.max(np.abs(encoded_t[rdx][0,:,0,channel_dx]))
                                if t_max < 0.01:
                                    t_max = 1
                                encoded_t[rdx][0,:,0,channel_dx] /= t_max
                                #print('Concate 6 OK')
                            siamese_input_list.append(encoded_t[rdx])
                            siamese_input_list.append(encoded_s[rdx])
                    pred_res = siamese_model.predict(siamese_input_list)
                    siamese_s = np.argmax(pred_res[-1][0,:,0,0])
                    pred_amp = pred_res[-1][0,siamese_s,0,0]
                    
                    if pred_amp > 0.1 and siamese_s > 800 and siamese_s < 5200:
                        siamese_s_time = obspy.UTCDateTime(search_key) + siamese_s * 0.01
                        t_update_time  = siamese_s_time - base_time
                        t_diff_time = siamese_s_time - (obspy.UTCDateTime(e_time[-27:]) + sst[0,0] * 60)
                        #r_snr = np.max(np.abs(data_s_in[0,siamese_s-50:siamese_s,0]))/np.max(np.abs(data_s_in[0,siamese_s:siamese_s+100,0]))
                        
                        if np.abs(t_diff_time) < 12:
                            pass
                        else:
                            #print(t_diff_time)
                            continue

                        max_pred_amp = pred_amp
                        s_pred_amp = pred_amp
                        siamese_s_time = obspy.UTCDateTime(search_key) + siamese_s * 0.01
                        t_update_time  = siamese_s_time - base_time
  
                        t_update_list.append(t_update_time)
                        t_update_list_prob.append(pred_amp)
                if len(t_update_list) > 0:
                    max_arg = np.argmax(t_update_list_prob)
                    t_update_time = t_update_list[max_arg]
                    bisect.insort(s_eqt_dict[search_sta[1]]['S'], t_update_time)
                    print('{}'.format(t_update_time))
    """
    plt.figure(figsize=(6,6))
    plt.scatter(sta[3],sta[2],color='r')
    for t_sta in search_list:
        plt.scatter(t_sta[3],t_sta[2],color='b')
    plt.xlim([-118.8,-118.0])
    plt.ylim([34.0,34.8])
    plt.show()
    plt.close()
    """
    # open search list csv and hdf5 file
    # for all high P
    #     for all search stations
    #        for all time within range
    #           calcualte P
    #           keep highest Prob
    #           check insert Point
    #
# Out:
# On 1 of 41
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# ALP_CI_HH_2010-01-04T20:08:00.002700Z
# REF TIME:331702.9427
# Skipping CI.VCS
# Skipping CI.LEO
# Skipping CI.STT
# Skipping CI.BTP
# COOL Go ahead
# ALP_CI_HH_2010-01-04T20:11:30.002700Z
# REF TIME:331909.5327
# Skipping CI.VCS
# Skipping CI.LEO
# Skipping CI.STT
# Skipping CI.BTP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# ALP_CI_HH_2010-01-13T20:31:30.002700Z
# REF TIME:1110695.9927
# Skipping CI.STT
# No GOOD SKIP
# COOL Go ahead
# ALP_CI_HH_2010-01-14T12:10:30.002700Z
# REF TIME:1167033.1527
# Skipping CI.VCS
# Skipping CI.LEO
# Skipping CI.STT
# Skipping CI.BTP
# COOL Go ahead
# ALP_CI_HH_2010-01-14T12:57:30.002700Z
# REF TIME:1169858.9827
# Skipping CI.VCS
# Skipping CI.LEO
# COOL Go ahead
# ALP_CI_HH_2010-01-14T19:07:00.002700Z
# REF TIME:1192027.9827
# Skipping CI.STT
# COOL Go ahead
# ALP_CI_HH_2010-01-14T19:07:00.002700Z
# REF TIME:1192027.9827
# Skipping CI.STT
# No GOOD SKIP
# COOL Go ahead
# ALP_CI_HH_2010-01-14T21:34:30.002700Z
# REF TIME:1200901.5627
# No GOOD SKIP
# COOL Go ahead
# ALP_CI_HH_2010-01-14T21:49:30.002700Z
# REF TIME:1201784.0727
# Skipping CI.LEO
# On 2 of 41
# COOL Go ahead
# VCS_CI_HH_2010-01-01T02:55:30.000700Z
# REF TIME:10535.0507
# Skipping CI.ALP
# Skipping CI.LEO
# Skipping CI.MWC
# COOL Go ahead
# VCS_CI_HH_2010-01-02T03:15:30.000700Z
# REF TIME:98164.7507
# Skipping CI.ALP
# Skipping CI.LEO
# Skipping CI.MWC
# COOL Go ahead
# VCS_CI_HH_2010-01-04T20:08:00.000700Z
# REF TIME:331704.6307
# Skipping CI.ALP
# Skipping CI.LEO
# Skipping CI.MWC
# Skipping CI.IR2
# COOL Go ahead
# VCS_CI_HH_2010-01-04T20:11:30.000700Z
# REF TIME:331910.4907
# Skipping CI.ALP
# Skipping CI.LEO
# Skipping CI.MWC
# Skipping CI.IR2
# COOL Go ahead
# VCS_CI_HH_2010-01-04T22:37:00.000700Z
# REF TIME:340657.2307
# 340671.8327
# Skipping CI.LEO
# Skipping CI.MWC
# Skipping CI.IR2
# COOL Go ahead
# VCS_CI_HH_2010-01-05T04:45:00.000700Z
# REF TIME:362712.9907
# Skipping CI.ALP
# Skipping CI.LEO
# Skipping CI.MWC
# Skipping CI.IR2
# COOL Go ahead
# VCS_CI_HH_2010-01-05T04:50:00.000700Z
# REF TIME:363016.0807
# Skipping CI.ALP
# Skipping CI.LEO
# Skipping CI.MWC
# Skipping CI.IR2
# COOL Go ahead
# VCS_CI_HH_2010-01-05T22:58:00.000700Z
# REF TIME:428286.9907
# COOL Go ahead
# VCS_CI_HH_2010-01-09T12:56:30.000700Z
# REF TIME:737794.1007
# Skipping CI.ALP
# Skipping CI.LEO
# Skipping CI.MWC
# Skipping CI.IR2
# COOL Go ahead
# VCS_CI_HH_2010-01-10T00:29:30.000700Z
# REF TIME:779377.0007
# Skipping CI.LEO
# Skipping CI.MWC
# Skipping CI.IR2
# COOL Go ahead
# VCS_CI_HH_2010-01-10T02:55:30.000700Z
# REF TIME:788142.6007
# Skipping CI.ALP
# Skipping CI.LEO
# Skipping CI.MWC
# Skipping CI.IR2
# No GOOD SKIP
# COOL Go ahead
# VCS_CI_HH_2010-01-10T22:40:30.000700Z
# REF TIME:859252.4907
# Skipping CI.LEO
# Skipping CI.MWC
# Skipping CI.IR2
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# VCS_CI_HH_2010-01-13T00:56:00.000700Z
# REF TIME:1040183.9907
# Skipping CI.ALP
# Skipping CI.LEO
# Skipping CI.MWC
# Skipping CI.IR2
# COOL Go ahead
# VCS_CI_HH_2010-01-14T08:15:30.000700Z
# REF TIME:1152943.4707
# Skipping CI.ALP
# Skipping CI.LEO
# Skipping CI.MWC
# Skipping CI.IR2
# COOL Go ahead
# VCS_CI_HH_2010-01-14T12:10:30.000700Z
# REF TIME:1167035.0507
# Skipping CI.ALP
# Skipping CI.LEO
# Skipping CI.MWC
# Skipping CI.IR2
# No GOOD SKIP
# No GOOD SKIP
# On 3 of 41
# COOL Go ahead
# GSA_CI_HN_2010-01-05T18:13:30.000700Z
# REF TIME:411215.1207
# Skipping CI.RHC
# Skipping CI.USC
# Skipping CI.LCG
# COOL Go ahead
# GSA_CI_HN_2010-01-12T02:36:00.000700Z
# REF TIME:959787.4507
# Skipping CI.WNS
# Skipping CI.MIKB
# Skipping CI.RHC
# Skipping CI.USC
# Skipping CI.DEC
# Skipping CI.CBC
# Skipping CI.LCG
# Skipping CI.MWC
# Skipping CI.RUS
# Skipping CI.PASC
# Skipping CI.KIK
# Skipping CI.GVR
# Skipping CI.MIK
# Skipping CI.HLL
# On 4 of 41
# No GOOD SKIP
# COOL Go ahead
# WNS_CI_HN_2010-01-05T04:50:00.002700Z
# REF TIME:363013.9827
# Skipping CI.MIKB
# Skipping CI.WSS
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.DJJ
# Skipping CI.LFP
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.GVR
# Skipping CI.SPF
# Skipping CI.MIK
# Skipping CI.HLL
# COOL Go ahead
# WNS_CI_HN_2010-01-06T01:58:00.002700Z
# REF TIME:439132.6227
# Skipping CI.NOT
# Skipping CI.LCG
# COOL Go ahead
# WNS_CI_HN_2010-01-07T00:44:00.008800Z
# REF TIME:521055.5088
# 521062.7885
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.SPF
# COOL Go ahead
# WNS_CI_HN_2010-01-07T00:44:00.008800Z
# REF TIME:521055.5088
# Skipping CI.DEC
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.SPF
# No GOOD SKIP
# COOL Go ahead
# WNS_CI_HN_2010-01-07T02:13:30.008800Z
# REF TIME:526438.1688
# Skipping CI.GSA
# Skipping CI.LCG
# COOL Go ahead
# WNS_CI_HN_2010-01-07T02:13:30.008800Z
# REF TIME:526438.1688
# Skipping CI.GSA
# Skipping CI.LCG
# COOL Go ahead
# WNS_CI_HN_2010-01-07T20:21:30.008800Z
# REF TIME:591712.2188
# Skipping CI.NOT
# Skipping CI.LCG
# Skipping CI.PASC
# Skipping CI.MIK
# COOL Go ahead
# WNS_CI_HN_2010-01-07T20:45:00.008800Z
# REF TIME:593146.8588
# Skipping CI.KIK
# Skipping CI.SPF
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# WNS_CI_HN_2010-01-07T22:42:00.008800Z
# REF TIME:600138.2788
# Skipping CI.USC
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.KIK
# COOL Go ahead
# WNS_CI_HN_2010-01-07T22:42:00.008800Z
# REF TIME:600138.2788
# Skipping CI.USC
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.KIK
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# WNS_CI_HN_2010-01-09T14:26:00.008800Z
# REF TIME:743186.3788
# Skipping CI.USC
# Skipping CI.SMS
# Skipping CI.KIK
# COOL Go ahead
# WNS_CI_HN_2010-01-09T17:29:00.008800Z
# REF TIME:754147.0688
# COOL Go ahead
# WNS_CI_HN_2010-01-09T17:29:00.008800Z
# REF TIME:754147.0688
# COOL Go ahead
# WNS_CI_HN_2010-01-09T20:04:00.008800Z
# REF TIME:763473.4988
# 763480.8707
# Skipping CI.NOT
# Skipping CI.DJJ
# COOL Go ahead
# WNS_CI_HN_2010-01-10T00:03:00.004800Z
# REF TIME:777810.3248
# Skipping CI.NOT
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# WNS_CI_HN_2010-01-10T15:49:00.004800Z
# REF TIME:834567.8348
# Search_keys Error
# Skipping CI.DJJB
# Skipping CI.KIK
# COOL Go ahead
# WNS_CI_HN_2010-01-10T15:49:00.004800Z
# REF TIME:834567.8348
# Search_keys Error
# Skipping CI.DJJB
# Skipping CI.KIK
# COOL Go ahead
# WNS_CI_HN_2010-01-10T15:49:00.004800Z
# REF TIME:834567.8348
# Search_keys Error
# Skipping CI.DJJB
# Skipping CI.KIK
# COOL Go ahead
# WNS_CI_HN_2010-01-10T15:58:30.004800Z
# REF TIME:835133.6748
# Search_keys Error
# 835127.1183
# No GOOD SKIP
# COOL Go ahead
# WNS_CI_HN_2010-01-10T17:10:30.004800Z
# REF TIME:839472.4648
# Skipping CI.USC
# Search_keys Error
# Skipping CI.LCG
# 839471.2746
# Skipping CI.RUS
# Skipping CI.CAC
# COOL Go ahead
# WNS_CI_HN_2010-01-10T17:10:30.004800Z
# REF TIME:839472.4648
# Skipping CI.USC
# 839481.2785
# Search_keys Error
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.RUS
# Skipping CI.CAC
# COOL Go ahead
# WNS_CI_HN_2010-01-10T17:36:30.004800Z
# REF TIME:841046.3248
# Skipping CI.NOT
# Search_keys Error
# 841059.1148
# Skipping CI.PASC
# Skipping CI.KIK
# Skipping CI.GVR
# COOL Go ahead
# WNS_CI_HN_2010-01-10T17:49:00.004800Z
# REF TIME:841757.1748
# Skipping CI.DEC
# 841773.6765
# Search_keys Error
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.MIK
# COOL Go ahead
# WNS_CI_HN_2010-01-11T01:58:30.008500Z
# REF TIME:871128.8585
# Skipping CI.RIN
# Search_keys Error
# Skipping CI.DJJB
# 871143.6883
# Skipping CI.CAC
# COOL Go ahead
# WNS_CI_HN_2010-01-11T01:58:30.008500Z
# REF TIME:871128.8585
# Skipping CI.RIN
# Search_keys Error
# Skipping CI.DJJB
# Skipping CI.RINB
# Skipping CI.CAC
# COOL Go ahead
# WNS_CI_HN_2010-01-12T02:36:00.006700Z
# REF TIME:959790.8267
# Skipping CI.GSA
# Skipping CI.RIN
# Skipping CI.MIKB
# Skipping CI.WSS
# Skipping CI.USC
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.CBC
# Skipping CI.DJJ
# Search_keys Error
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.RUS
# Skipping CI.PASC
# Skipping CI.KIK
# Skipping CI.RINB
# Skipping CI.GVR
# Skipping CI.SPF
# Skipping CI.MIK
# Skipping CI.HLL
# COOL Go ahead
# WNS_CI_HN_2010-01-12T22:45:30.006700Z
# REF TIME:1032363.1967
# Search_keys Error
# Skipping CI.SPF
# COOL Go ahead
# WNS_CI_HN_2010-01-13T00:56:00.000700Z
# REF TIME:1040177.1007
# Skipping CI.WSS
# Skipping CI.USC
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.DJJ
# Search_keys Error
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.RUS
# Skipping CI.PASC
# Skipping CI.GVR
# Skipping CI.SPF
# No GOOD SKIP
# COOL Go ahead
# WNS_CI_HN_2010-01-14T02:01:00.002700Z
# REF TIME:1130462.3927
# Search_keys Error
# On 5 of 41
# COOL Go ahead
# LEO_CI_EH_2010-01-01T02:55:30.000000Z
# REF TIME:10534.0
# Skipping CI.ALP
# Skipping CI.VCS
# Skipping CI.BTP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# LEO_CI_EH_2010-01-02T07:58:00.001100Z
# REF TIME:115096.1811
# Skipping CI.IR2
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# LEO_CI_EH_2010-01-03T19:51:30.009900Z
# REF TIME:244299.9799
# COOL Go ahead
# LEO_CI_EH_2010-01-03T20:40:00.009900Z
# REF TIME:247204.0399
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# LEO_CI_EH_2010-01-04T20:52:30.005800Z
# REF TIME:334385.8258
# Skipping CI.IR2
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# LEO_CI_EH_2010-01-07T09:12:00.000000Z
# REF TIME:551530.6
# Skipping CI.STT
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# LEO_CI_EH_2010-01-08T14:50:00.000000Z
# REF TIME:658208.06
# Skipping CI.STT
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# LEO_CI_EH_2010-01-10T13:48:00.000000Z
# REF TIME:827335.06
# Skipping CI.ALP
# Skipping CI.VCS
# Skipping CI.IR2
# Skipping CI.STT
# Skipping CI.BTP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# LEO_CI_EH_2010-01-11T00:35:30.009900Z
# REF TIME:866160.3699
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# LEO_CI_EH_2010-01-11T09:13:30.009900Z
# REF TIME:897218.7099
# Skipping CI.STT
# COOL Go ahead
# LEO_CI_EH_2010-01-11T12:08:30.009900Z
# REF TIME:907748.9399
# Skipping CI.STT
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# LEO_CI_EH_2010-01-11T19:53:30.009900Z
# REF TIME:935616.0099
# Skipping CI.ALP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# LEO_CI_EH_2010-01-14T11:08:00.000000Z
# REF TIME:1163289.0
# Skipping CI.ALP
# Skipping CI.VCS
# Skipping CI.IR2
# Skipping CI.STT
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# On 6 of 41
# On 7 of 41
# COOL Go ahead
# MIKB_CI_HN_2010-01-11T23:34:00.004400Z
# REF TIME:948852.3944
# Skipping CI.GSA
# Skipping CI.WNS
# Skipping CI.RHC
# Skipping CI.USC
# Skipping CI.DEC
# Skipping CI.CBC
# Skipping CI.LCG
# Skipping CI.MWC
# Skipping CI.RUS
# Skipping CI.PASC
# Skipping CI.GVR
# Skipping CI.MIK
# Skipping CI.HLL
# COOL Go ahead
# MIKB_CI_HN_2010-01-12T02:36:00.004400Z
# REF TIME:959787.4544
# Skipping CI.GSA
# Skipping CI.WNS
# Skipping CI.RHC
# Skipping CI.USC
# Skipping CI.DEC
# Skipping CI.CBC
# Skipping CI.LCG
# Skipping CI.MWC
# Skipping CI.RUS
# Skipping CI.PASC
# Skipping CI.KIK
# Skipping CI.GVR
# Skipping CI.MIK
# Skipping CI.HLL
# On 8 of 41
# No GOOD SKIP
# COOL Go ahead
# WSS_CI_HH_2010-01-11T23:24:00.006500Z
# REF TIME:948266.8665
# Skipping CI.WNS
# Skipping CI.SMV
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.QUG
# Skipping CI.BLC
# Skipping CI.DJJ
# Search_keys Error
# Skipping CI.AGO
# Skipping CI.DJJB
# Skipping CI.OAT
# Skipping CI.SPF
# Skipping CI.HLL
# COOL Go ahead
# WSS_CI_HH_2010-01-11T23:34:00.006500Z
# REF TIME:948859.0965
# Skipping CI.WNS
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.SMF
# Skipping CI.QUG
# Skipping CI.BLC
# Skipping CI.DJJ
# Search_keys Error
# Skipping CI.DJJB
# Skipping CI.OAT
# Skipping CI.SPF
# Skipping CI.HLL
# COOL Go ahead
# WSS_CI_HH_2010-01-12T02:36:30.006500Z
# REF TIME:959795.0065
# Skipping CI.WNS
# Skipping CI.RIN
# Skipping CI.SMV
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.QUG
# Skipping CI.BLC
# Skipping CI.DJJ
# Search_keys Error
# Skipping CI.AGO
# Skipping CI.DJJB
# Skipping CI.RINB
# Skipping CI.SPF
# Skipping CI.HLL
# COOL Go ahead
# WSS_CI_HH_2010-01-14T15:28:30.006500Z
# REF TIME:1178941.5565
# Skipping CI.SMS
# Skipping CI.BLC
# Skipping CI.DJJ
# Search_keys Error
# Skipping CI.OAT
# Skipping CI.SPF
# COOL Go ahead
# WSS_CI_HH_2010-01-14T20:16:30.006500Z
# REF TIME:1196231.1265
# Skipping CI.SMS
# Search_keys Error
# COOL Go ahead
# WSS_CI_HH_2010-01-14T20:16:30.006500Z
# REF TIME:1196231.1265
# 1196224.63
# Skipping CI.SMS
# Search_keys Error
# On 9 of 41
# COOL Go ahead
# OSI_CI_HH_2010-01-02T03:15:30.004300Z
# REF TIME:98164.4843
# Skipping CI.PDE
# Skipping CI.QAL
# Skipping CI.BTP
# COOL Go ahead
# OSI_CI_HH_2010-01-02T08:28:00.004300Z
# REF TIME:116926.7643
# Skipping CI.VVD
# Skipping CI.QAL
# COOL Go ahead
# OSI_CI_HH_2010-01-04T00:03:00.004300Z
# REF TIME:259385.0043
# Skipping CI.VVD
# Skipping CI.PDE
# Skipping CI.QAL
# Skipping CI.BTP
# No GOOD SKIP
# COOL Go ahead
# OSI_CI_HH_2010-01-07T09:58:30.004300Z
# REF TIME:554315.9843
# COOL Go ahead
# OSI_CI_HH_2010-01-08T02:36:00.004300Z
# REF TIME:614186.1643
# Skipping CI.VVD
# Skipping CI.QAL
# COOL Go ahead
# OSI_CI_HH_2010-01-09T10:29:00.004300Z
# REF TIME:728949.0143
# Skipping CI.VVD
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# OSI_CI_HH_2010-01-11T17:49:00.004300Z
# REF TIME:928147.0143
# Skipping CI.PDE
# Skipping CI.QAL
# No GOOD SKIP
# COOL Go ahead
# OSI_CI_HH_2010-01-12T02:36:30.004300Z
# REF TIME:959797.0043
# Skipping CI.VVD
# Skipping CI.PDE
# Skipping CI.QAL
# Skipping CI.BTP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# On 10 of 41
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# RHC_CI_EH_2010-01-02T04:04:30.009900Z
# REF TIME:101090.8499
# No GOOD SKIP
# COOL Go ahead
# RHC_CI_EH_2010-01-04T01:22:30.000000Z
# REF TIME:264156.01
# Skipping CI.USC
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# On 11 of 41
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# VVD_CI_EH_2010-01-05T07:49:00.000200Z
# REF TIME:373747.1102
# Skipping CI.NOT
# Skipping CI.BLC
# Skipping CI.IR2
# Skipping CI.OAT
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# VVD_CI_EH_2010-01-10T04:59:00.001300Z
# REF TIME:795576.6513
# Skipping CI.OSI
# Skipping CI.NOT
# Skipping CI.BLC
# Skipping CI.PDE
# Skipping CI.IR2
# Skipping CI.OAT
# Skipping CI.BTP
# COOL Go ahead
# VVD_CI_EH_2010-01-11T08:59:30.000000Z
# REF TIME:896394.66
# Skipping CI.OSI
# Skipping CI.QUG
# Skipping CI.BLC
# Search_keys Error
# Skipping CI.PDE
# Skipping CI.IR2
# Skipping CI.OAT
# COOL Go ahead
# VVD_CI_EH_2010-01-11T10:38:00.000000Z
# REF TIME:902316.87
# Skipping CI.RIN
# Skipping CI.OSI
# Skipping CI.SMV
# Skipping CI.QUG
# Skipping CI.BLC
# Search_keys Error
# Skipping CI.PDE
# Skipping CI.IR2
# Skipping CI.OAT
# Skipping CI.RINB
# COOL Go ahead
# VVD_CI_EH_2010-01-11T10:50:00.000000Z
# REF TIME:903026.18
# Skipping CI.RIN
# Skipping CI.SMV
# Skipping CI.NOT
# Skipping CI.BLC
# Search_keys Error
# Skipping CI.IR2
# Skipping CI.OAT
# COOL Go ahead
# VVD_CI_EH_2010-01-11T10:58:30.000000Z
# REF TIME:903555.58
# Skipping CI.NOT
# Skipping CI.QUG
# Skipping CI.BLC
# Search_keys Error
# Skipping CI.IR2
# Skipping CI.OAT
# COOL Go ahead
# VVD_CI_EH_2010-01-11T11:00:00.000000Z
# REF TIME:903632.28
# Skipping CI.NOT
# Skipping CI.BLC
# Search_keys Error
# Skipping CI.IR2
# Skipping CI.OAT
# COOL Go ahead
# VVD_CI_EH_2010-01-11T22:20:00.000000Z
# REF TIME:944448.46
# Skipping CI.QUG
# Skipping CI.BLC
# Search_keys Error
# Skipping CI.PDE
# Skipping CI.IR2
# Skipping CI.OAT
# Skipping CI.BTP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# VVD_CI_EH_2010-01-14T02:28:30.001300Z
# REF TIME:1132138.9713
# Skipping CI.NOT
# Search_keys Error
# Skipping CI.IR2
# Skipping CI.OAT
# Skipping CI.RINB
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# On 12 of 41
# No GOOD SKIP
# COOL Go ahead
# USC_CI_HH_2010-01-05T09:12:30.008300Z
# REF TIME:378756.0783
# Skipping CI.DJJB
# Skipping CI.KIK
# COOL Go ahead
# USC_CI_HH_2010-01-08T07:39:00.008300Z
# REF TIME:632345.7983
# 632348.07
# Skipping CI.DJJ
# 632356.2348
# No GOOD SKIP
# COOL Go ahead
# USC_CI_HH_2010-01-12T11:17:00.008300Z
# REF TIME:991026.4383
# 991031.0585
# Skipping CI.LCG
# Skipping CI.RUS
# 991034.15
# COOL Go ahead
# USC_CI_HH_2010-01-12T12:34:30.008300Z
# REF TIME:995674.6583
# COOL Go ahead
# USC_CI_HH_2010-01-13T00:55:30.008300Z
# REF TIME:1040176.2183
# Skipping CI.WNS
# Skipping CI.RHC
# Skipping CI.DEC
# Skipping CI.SMS
# Skipping CI.DJJ
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.RUS
# Skipping CI.PASC
# 1040187.9
# Skipping CI.GVR
# COOL Go ahead
# USC_CI_HH_2010-01-13T07:04:00.008300Z
# REF TIME:1062280.3183
# Skipping CI.LCG
# Skipping CI.PASC
# COOL Go ahead
# USC_CI_HH_2010-01-14T06:50:00.008300Z
# REF TIME:1147806.2683
# Skipping CI.DEC
# Skipping CI.SMF
# Skipping CI.LCG
# COOL Go ahead
# USC_CI_HH_2010-01-14T06:50:00.008300Z
# REF TIME:1147806.2683
# Skipping CI.DEC
# Skipping CI.SMF
# Skipping CI.LCG
# COOL Go ahead
# USC_CI_HH_2010-01-14T07:36:00.008300Z
# REF TIME:1150571.2183
# Skipping CI.WNS
# Skipping CI.RHC
# Skipping CI.LCG
# Skipping CI.DJJB
# COOL Go ahead
# USC_CI_HH_2010-01-14T07:36:00.008300Z
# REF TIME:1150571.2183
# Skipping CI.WNS
# Skipping CI.RHC
# Skipping CI.LCG
# Skipping CI.DJJB
# On 13 of 41
# COOL Go ahead
# DEC_CI_HH_2010-01-01T22:20:00.008500Z
# REF TIME:80428.9885
# Skipping CI.SMS
# Skipping CI.DJJ
# Skipping CI.LFP
# Skipping CI.MWC
# Skipping CI.DJJB
# Skipping CI.PASC
# COOL Go ahead
# DEC_CI_HH_2010-01-02T03:15:30.008500Z
# REF TIME:98160.4885
# Skipping CI.GSA
# Skipping CI.WNS
# Skipping CI.MIKB
# Skipping CI.USC
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.CBC
# Skipping CI.QUG
# Skipping CI.DJJ
# Skipping CI.LFP
# Skipping CI.LCG
# Skipping CI.MWC
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.GVR
# Skipping CI.MIK
# Skipping CI.HLL
# COOL Go ahead
# DEC_CI_HH_2010-01-04T20:08:00.008500Z
# REF TIME:331710.5185
# Skipping CI.GSA
# Skipping CI.WNS
# Skipping CI.MIKB
# Skipping CI.SMS
# Skipping CI.SMF
# Skipping CI.CBC
# Skipping CI.QUG
# Skipping CI.DJJ
# Skipping CI.LFP
# Skipping CI.LCG
# Skipping CI.MWC
# Skipping CI.DJJB
# Skipping CI.IR2
# Skipping CI.PASC
# Skipping CI.OAT
# Skipping CI.GVR
# Skipping CI.HLL
# 331728.86
# COOL Go ahead
# DEC_CI_HH_2010-01-04T20:08:30.008500Z
# REF TIME:331714.0285
# Skipping CI.GSA
# Skipping CI.WNS
# Skipping CI.MIKB
# Skipping CI.SMS
# Skipping CI.SMF
# Skipping CI.CBC
# Skipping CI.QUG
# Skipping CI.DJJ
# Skipping CI.LFP
# Skipping CI.LCG
# Skipping CI.MWC
# Skipping CI.DJJB
# Skipping CI.IR2
# Skipping CI.PASC
# Skipping CI.OAT
# Skipping CI.GVR
# Skipping CI.HLL
# Skipping CI.CAC
# COOL Go ahead
# DEC_CI_HH_2010-01-04T20:11:30.008500Z
# REF TIME:331915.9885
# Skipping CI.SMS
# Skipping CI.SMF
# Skipping CI.DJJ
# Skipping CI.LFP
# Skipping CI.MWC
# Skipping CI.DJJB
# Skipping CI.IR2
# Skipping CI.PASC
# Skipping CI.OAT
# Skipping CI.GVR
# COOL Go ahead
# DEC_CI_HH_2010-01-05T04:49:30.008500Z
# REF TIME:363014.0385
# Skipping CI.WNS
# Skipping CI.MIKB
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.DJJ
# Skipping CI.LFP
# Skipping CI.LCG
# Skipping CI.MWC
# Skipping CI.DJJB
# Skipping CI.IR2
# Skipping CI.PASC
# Skipping CI.OAT
# Skipping CI.GVR
# Skipping CI.MIK
# Skipping CI.HLL
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# DEC_CI_HH_2010-01-10T12:45:30.008500Z
# REF TIME:823537.9985
# Skipping CI.NOT
# Skipping CI.MWC
# Skipping CI.OAT
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# DEC_CI_HH_2010-01-11T10:38:00.008500Z
# REF TIME:902320.3785
# Skipping CI.RIN
# Skipping CI.QUG
# Skipping CI.DJJ
# Search_keys Error
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.IR2
# Skipping CI.OAT
# Skipping CI.RINB
# COOL Go ahead
# DEC_CI_HH_2010-01-11T23:24:00.008500Z
# REF TIME:948262.8785
# Skipping CI.GSA
# Skipping CI.WNS
# Skipping CI.MIKB
# Skipping CI.USC
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.CBC
# Skipping CI.QUG
# Skipping CI.DJJ
# Search_keys Error
# Skipping CI.LCG
# Skipping CI.MWC
# Skipping CI.DJJB
# Skipping CI.IR2
# Skipping CI.PASC
# Skipping CI.KIK
# Skipping CI.OAT
# Skipping CI.GVR
# Skipping CI.MIK
# Skipping CI.HLL
# COOL Go ahead
# DEC_CI_HH_2010-01-11T23:34:00.008500Z
# REF TIME:948855.0985
# Skipping CI.GSA
# Skipping CI.WNS
# Skipping CI.MIKB
# Skipping CI.USC
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.SMF
# Skipping CI.CBC
# Skipping CI.QUG
# Skipping CI.DJJ
# Search_keys Error
# Skipping CI.LCG
# Skipping CI.MWC
# Skipping CI.DJJB
# Skipping CI.IR2
# Skipping CI.PASC
# Skipping CI.OAT
# Skipping CI.GVR
# Skipping CI.MIK
# Skipping CI.HLL
# No GOOD SKIP
# COOL Go ahead
# DEC_CI_HH_2010-01-13T00:56:00.008500Z
# REF TIME:1040179.3385
# Skipping CI.WNS
# Skipping CI.USC
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.DJJ
# Search_keys Error
# Skipping CI.LCG
# Skipping CI.MWC
# Skipping CI.DJJB
# Skipping CI.IR2
# Skipping CI.PASC
# Skipping CI.KIK
# Skipping CI.OAT
# Skipping CI.GVR
# No GOOD SKIP
# COOL Go ahead
# DEC_CI_HH_2010-01-14T12:57:30.008500Z
# REF TIME:1169866.8985
# Skipping CI.WNS
# Skipping CI.USC
# Skipping CI.SMS
# Skipping CI.SMF
# Skipping CI.QUG
# Skipping CI.DJJ
# Search_keys Error
# Skipping CI.MWC
# Skipping CI.DJJB
# Skipping CI.IR2
# Skipping CI.PASC
# Skipping CI.OAT
# Skipping CI.GVR
# No GOOD SKIP
# On 14 of 41
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# SMV_CI_EH_2010-01-01T12:47:30.000000Z
# REF TIME:46088.98
# Skipping CI.NOT
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# SMV_CI_EH_2010-01-01T15:53:30.000000Z
# REF TIME:57247.67
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# SMV_CI_EH_2010-01-01T20:21:00.000000Z
# REF TIME:73295.77
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# SMV_CI_EH_2010-01-03T15:56:30.000000Z
# REF TIME:230223.51
# Skipping CI.NOT
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# SMV_CI_EH_2010-01-04T05:33:00.000000Z
# REF TIME:279185.01
# Skipping CI.VVD
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# SMV_CI_EH_2010-01-04T19:33:00.000000Z
# REF TIME:329611.97
# No GOOD SKIP
# COOL Go ahead
# SMV_CI_EH_2010-01-04T20:08:00.000000Z
# REF TIME:331690.33
# Skipping CI.WSS
# Skipping CI.QUG
# Skipping CI.BLC
# Skipping CI.LFP
# Skipping CI.OAT
# Skipping CI.SPF
# COOL Go ahead
# SMV_CI_EH_2010-01-04T20:08:00.000000Z
# REF TIME:331690.33
# Skipping CI.WSS
# Skipping CI.QUG
# Skipping CI.BLC
# Skipping CI.LFP
# Skipping CI.OAT
# Skipping CI.SPF
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# SMV_CI_EH_2010-01-05T03:01:00.000000Z
# REF TIME:356492.01
# Skipping CI.WSS
# Skipping CI.VVD
# Skipping CI.NOT
# Skipping CI.AGO
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# SMV_CI_EH_2010-01-06T07:23:30.000000Z
# REF TIME:458640.99
# 458657.1902
# Skipping CI.QUG
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# SMV_CI_EH_2010-01-06T09:08:30.000000Z
# REF TIME:464946.96
# Skipping CI.VVD
# Skipping CI.LFP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# SMV_CI_EH_2010-01-07T00:17:00.000000Z
# REF TIME:519435.96
# Skipping CI.VVD
# Skipping CI.NOT
# 519459.84
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# SMV_CI_EH_2010-01-09T08:02:00.000000Z
# REF TIME:720124.89
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# SMV_CI_EH_2010-01-14T19:06:00.000000Z
# REF TIME:1191964.02
# Skipping CI.QUG
# Search_keys Error
# No GOOD SKIP
# No GOOD SKIP
# On 15 of 41
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# NOT_CI_EH_2010-01-02T15:15:30.000000Z
# REF TIME:141340.23
# Skipping CI.AGO
# 141340.5546
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# NOT_CI_EH_2010-01-05T09:32:30.000000Z
# REF TIME:379999.19
# Skipping CI.LFP
# COOL Go ahead
# NOT_CI_EH_2010-01-05T10:29:30.000000Z
# REF TIME:383396.22
# Skipping CI.SMV
# Skipping CI.DJJB
# 383409.9104
# No GOOD SKIP
# COOL Go ahead
# NOT_CI_EH_2010-01-05T13:58:00.000000Z
# REF TIME:395885.62
# Skipping CI.VVD
# Skipping CI.PDE
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# NOT_CI_EH_2010-01-08T20:38:30.000000Z
# REF TIME:679117.97
# Skipping CI.SMV
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# NOT_CI_EH_2010-01-10T00:00:00.000000Z
# REF TIME:777608.13
# Skipping CI.SMV
# Skipping CI.PDE
# Skipping CI.OAT
# Skipping CI.RINB
# Skipping CI.SPF
# COOL Go ahead
# NOT_CI_EH_2010-01-10T13:39:30.000000Z
# REF TIME:826785.42
# Skipping CI.SMV
# 826789.2613
# Skipping CI.OAT
# COOL Go ahead
# NOT_CI_EH_2010-01-10T15:52:30.000000Z
# REF TIME:834760.34
# 834774.0888
# Search_keys Error
# Skipping CI.PDE
# No GOOD SKIP
# COOL Go ahead
# NOT_CI_EH_2010-01-11T16:20:30.000000Z
# REF TIME:922839.88
# Skipping CI.DEC
# Search_keys Error
# Skipping CI.DJJB
# COOL Go ahead
# NOT_CI_EH_2010-01-11T16:20:30.000000Z
# REF TIME:922839.88
# Skipping CI.DEC
# Search_keys Error
# Skipping CI.DJJB
# COOL Go ahead
# NOT_CI_EH_2010-01-11T16:48:30.000000Z
# REF TIME:924526.9
# Skipping CI.WSS
# Search_keys Error
# COOL Go ahead
# NOT_CI_EH_2010-01-11T19:31:00.000000Z
# REF TIME:934265.93
# Skipping CI.DEC
# Search_keys Error
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# NOT_CI_EH_2010-01-13T11:16:00.000000Z
# REF TIME:1077385.28
# 1077376.7985
# Skipping CI.DJJ
# Search_keys Error
# Skipping CI.AGO
# Skipping CI.OAT
# Skipping CI.SPF
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# NOT_CI_EH_2010-01-13T22:47:00.000000Z
# REF TIME:1118825.06
# Skipping CI.VVD
# Search_keys Error
# Skipping CI.DJJB
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# NOT_CI_EH_2010-01-14T03:55:00.000000Z
# REF TIME:1137305.2
# Search_keys Error
# Skipping CI.DJJB
# COOL Go ahead
# NOT_CI_EH_2010-01-14T20:52:30.000000Z
# REF TIME:1198359.5
# Search_keys Error
# No GOOD SKIP
# On 16 of 41
# COOL Go ahead
# SMS_CI_HH_2010-01-02T03:15:30.006500Z
# REF TIME:98155.7765
# Skipping CI.WNS
# Skipping CI.USC
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.DJJ
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.SPF
# Skipping CI.HLL
# COOL Go ahead
# SMS_CI_HH_2010-01-02T05:38:30.006500Z
# REF TIME:106729.6265
# Skipping CI.LCG
# Skipping CI.DJJB
# COOL Go ahead
# SMS_CI_HH_2010-01-02T05:38:30.006500Z
# REF TIME:106729.6265
# Skipping CI.LCG
# Skipping CI.DJJB
# No GOOD SKIP
# COOL Go ahead
# SMS_CI_HH_2010-01-04T20:08:30.006500Z
# REF TIME:331716.0365
# Skipping CI.WNS
# Skipping CI.WSS
# Skipping CI.DEC
# Skipping CI.SMF
# Skipping CI.DJJ
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.SPF
# Skipping CI.HLL
# COOL Go ahead
# SMS_CI_HH_2010-01-05T04:50:00.006500Z
# REF TIME:363015.2265
# Skipping CI.WNS
# Skipping CI.WSS
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.DJJ
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.SPF
# Skipping CI.HLL
# COOL Go ahead
# SMS_CI_HH_2010-01-06T07:06:00.006500Z
# REF TIME:457570.4165
# Skipping CI.LCG
# COOL Go ahead
# SMS_CI_HH_2010-01-06T10:43:00.006500Z
# REF TIME:470624.1965
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.DJJ
# Skipping CI.LCG
# Skipping CI.SPF
# COOL Go ahead
# SMS_CI_HH_2010-01-06T10:43:00.006500Z
# REF TIME:470624.1965
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.DJJ
# Skipping CI.LCG
# Skipping CI.SPF
# COOL Go ahead
# SMS_CI_HH_2010-01-08T00:22:30.006500Z
# REF TIME:606171.1665
# COOL Go ahead
# SMS_CI_HH_2010-01-08T01:00:00.006500Z
# REF TIME:608409.4665
# Skipping CI.DEC
# Skipping CI.LCG
# COOL Go ahead
# SMS_CI_HH_2010-01-08T08:05:00.006500Z
# REF TIME:633906.4865
# Skipping CI.USC
# Skipping CI.DJJB
# Skipping CI.SPF
# COOL Go ahead
# SMS_CI_HH_2010-01-08T12:08:00.006500Z
# REF TIME:648484.4465
# Skipping CI.DJJB
# COOL Go ahead
# SMS_CI_HH_2010-01-08T12:08:00.006500Z
# REF TIME:648484.4465
# Skipping CI.DJJB
# No GOOD SKIP
# COOL Go ahead
# SMS_CI_HH_2010-01-11T23:34:00.006500Z
# REF TIME:948856.4365
# Skipping CI.WNS
# Skipping CI.WSS
# Skipping CI.USC
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.SMF
# Skipping CI.DJJ
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.SPF
# Skipping CI.HLL
# No GOOD SKIP
# COOL Go ahead
# SMS_CI_HH_2010-01-12T08:48:00.006500Z
# REF TIME:982087.9465
# Skipping CI.NOT
# Skipping CI.LCG
# COOL Go ahead
# SMS_CI_HH_2010-01-13T00:56:00.006500Z
# REF TIME:1040176.6965
# Skipping CI.WNS
# Skipping CI.WSS
# Skipping CI.USC
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.DJJ
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.SPF
# On 17 of 41
# COOL Go ahead
# SMF_CI_EH_2010-01-02T18:11:10.779900Z
# REF TIME:151906.5299
# 151905.9865
# COOL Go ahead
# SMF_CI_EH_2010-01-03T01:43:00.000000Z
# REF TIME:178992.24
# Skipping CI.WSS
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.PASC
# COOL Go ahead
# SMF_CI_EH_2010-01-03T16:55:00.000000Z
# REF TIME:233723.84
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# SMF_CI_EH_2010-01-08T05:21:00.000000Z
# REF TIME:624101.3
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.PASC
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# SMF_CI_EH_2010-01-09T12:56:00.000000Z
# REF TIME:737784.47
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.DJJ
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.PASC
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# SMF_CI_EH_2010-01-12T18:35:00.001300Z
# REF TIME:1017341.0313
# Skipping CI.DJJ
# No GOOD SKIP
# COOL Go ahead
# SMF_CI_EH_2010-01-13T14:33:30.000900Z
# REF TIME:1089224.4709
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# SMF_CI_EH_2010-01-14T15:14:00.001300Z
# REF TIME:1178076.1213
# COOL Go ahead
# SMF_CI_EH_2010-01-14T22:14:00.001300Z
# REF TIME:1203257.4513
# Skipping CI.NOT
# Skipping CI.SPF
# No GOOD SKIP
# On 18 of 41
# No GOOD SKIP
# On 19 of 41
# COOL Go ahead
# QUG_CI_HN_2010-01-05T16:09:00.004100Z
# REF TIME:403773.3341
# Skipping CI.VVD
# Skipping CI.SMV
# 403779.3402
# COOL Go ahead
# QUG_CI_HN_2010-01-11T23:34:00.004100Z
# REF TIME:948858.4041
# Skipping CI.WSS
# Skipping CI.VVD
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.BLC
# Search_keys Error
# Skipping CI.IR2
# Skipping CI.OAT
# Skipping CI.HLL
# COOL Go ahead
# QUG_CI_HN_2010-01-12T00:16:00.004300Z
# REF TIME:951366.3843
# Skipping CI.WSS
# Skipping CI.SMV
# Search_keys Error
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# QUG_CI_HN_2010-01-14T13:37:30.004100Z
# REF TIME:1172254.0341
# Skipping CI.WSS
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.BLC
# Search_keys Error
# Skipping CI.IR2
# On 20 of 41
# No GOOD SKIP
# COOL Go ahead
# BLC_CI_EH_2010-01-05T04:55:30.000200Z
# REF TIME:363334.8302
# Skipping CI.VVD
# Skipping CI.NOT
# Skipping CI.DJJ
# Skipping CI.DJJB
# Skipping CI.IR2
# Skipping CI.OAT
# Skipping CI.SPF
# COOL Go ahead
# BLC_CI_EH_2010-01-05T05:14:00.000200Z
# REF TIME:364473.2502
# Skipping CI.VVD
# Skipping CI.DJJ
# Skipping CI.AGO
# Skipping CI.DJJB
# Skipping CI.IR2
# Skipping CI.OAT
# Skipping CI.SPF
# COOL Go ahead
# BLC_CI_EH_2010-01-05T05:14:00.000200Z
# REF TIME:364473.2502
# Skipping CI.VVD
# Skipping CI.DJJ
# Skipping CI.AGO
# Skipping CI.DJJB
# Skipping CI.IR2
# Skipping CI.OAT
# Skipping CI.SPF
# No GOOD SKIP
# COOL Go ahead
# BLC_CI_EH_2010-01-05T07:53:30.000200Z
# REF TIME:374035.6802
# Skipping CI.VVD
# Skipping CI.SMV
# Skipping CI.NOT
# Skipping CI.DJJ
# Skipping CI.AGO
# Skipping CI.DJJB
# Skipping CI.IR2
# Skipping CI.OAT
# Skipping CI.SPF
# COOL Go ahead
# BLC_CI_EH_2010-01-05T07:59:00.000200Z
# REF TIME:374380.2502
# Skipping CI.RIN
# Skipping CI.VVD
# Skipping CI.SMV
# Skipping CI.DJJ
# Skipping CI.LFP
# Skipping CI.PDE
# Skipping CI.AGO
# Skipping CI.DJJB
# Skipping CI.IR2
# Skipping CI.OAT
# Skipping CI.RINB
# Skipping CI.SPF
# COOL Go ahead
# BLC_CI_EH_2010-01-05T14:54:30.000200Z
# REF TIME:399293.7002
# Skipping CI.VVD
# Skipping CI.SMV
# Skipping CI.NOT
# Skipping CI.DJJ
# Skipping CI.PDE
# Skipping CI.DJJB
# Skipping CI.IR2
# Skipping CI.OAT
# No GOOD SKIP
# COOL Go ahead
# BLC_CI_EH_2010-01-08T06:29:00.000000Z
# REF TIME:628167.41
# Skipping CI.WSS
# Skipping CI.VVD
# Skipping CI.DJJ
# Skipping CI.DJJB
# Skipping CI.OAT
# Skipping CI.SPF
# COOL Go ahead
# BLC_CI_EH_2010-01-08T06:29:00.000000Z
# REF TIME:628167.41
# Skipping CI.WSS
# Skipping CI.VVD
# Skipping CI.DJJ
# Skipping CI.DJJB
# Skipping CI.OAT
# Skipping CI.SPF
# No GOOD SKIP
# COOL Go ahead
# BLC_CI_EH_2010-01-11T03:42:30.000000Z
# REF TIME:877391.86
# Skipping CI.WSS
# Skipping CI.VVD
# Search_keys Error
# 877394.5546
# Skipping CI.IR2
# Skipping CI.OAT
# Skipping CI.SPF
# COOL Go ahead
# BLC_CI_EH_2010-01-11T10:38:00.000000Z
# REF TIME:902317.58
# Skipping CI.RIN
# Skipping CI.VVD
# Skipping CI.SMV
# Skipping CI.QUG
# Skipping CI.DJJ
# Search_keys Error
# Skipping CI.PDE
# Skipping CI.AGO
# Skipping CI.DJJB
# Skipping CI.IR2
# Skipping CI.OAT
# Skipping CI.RINB
# Skipping CI.SPF
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# On 21 of 41
# COOL Go ahead
# DJJ_CI_HH_2010-01-01T00:48:00.008800Z
# REF TIME:2888.0388
# 2890.7148
# Skipping CI.USC
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.PASC
# COOL Go ahead
# DJJ_CI_HH_2010-01-01T02:55:30.008800Z
# REF TIME:10543.3388
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.PASC
# COOL Go ahead
# DJJ_CI_HH_2010-01-01T04:33:30.008800Z
# REF TIME:16465.2988
# Skipping CI.WNS
# Skipping CI.DEC
# Skipping CI.SMS
# Skipping CI.LCG
# Skipping CI.AGO
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.SPF
# COOL Go ahead
# DJJ_CI_HH_2010-01-01T06:17:30.008800Z
# REF TIME:22660.3788
# Skipping CI.WSS
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.RINB
# COOL Go ahead
# DJJ_CI_HH_2010-01-01T10:47:30.008800Z
# REF TIME:38885.3388
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.DJJB
# Skipping CI.SPF
# COOL Go ahead
# DJJ_CI_HH_2010-01-01T22:20:00.008800Z
# REF TIME:80428.8688
# Skipping CI.DEC
# Skipping CI.SMS
# Skipping CI.LFP
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.SPF
# COOL Go ahead
# DJJ_CI_HH_2010-01-01T22:20:30.008800Z
# REF TIME:80431.6188
# Skipping CI.DEC
# Skipping CI.SMS
# Skipping CI.LFP
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.SPF
# COOL Go ahead
# DJJ_CI_HH_2010-01-02T03:15:30.008800Z
# REF TIME:98156.6788
# Skipping CI.WNS
# 98165.0965
# Skipping CI.USC
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.LFP
# Skipping CI.LCG
# Skipping CI.AGO
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.SPF
# Skipping CI.HLL
# COOL Go ahead
# DJJ_CI_HH_2010-01-02T19:45:30.008800Z
# REF TIME:157535.8488
# Skipping CI.WNS
# 157548.9483
# Skipping CI.NOT
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.SPF
# COOL Go ahead
# DJJ_CI_HH_2010-01-03T03:36:00.008800Z
# REF TIME:185766.2188
# Skipping CI.SMS
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.PASC
# COOL Go ahead
# DJJ_CI_HH_2010-01-03T04:47:30.008800Z
# REF TIME:190095.6888
# Skipping CI.WNS
# Skipping CI.WSS
# Skipping CI.USC
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.AGO
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.SPF
# COOL Go ahead
# DJJ_CI_HH_2010-01-03T16:19:00.008800Z
# REF TIME:231558.3488
# Skipping CI.NOT
# Skipping CI.DJJB
# COOL Go ahead
# DJJ_CI_HH_2010-01-04T07:27:30.008800Z
# REF TIME:286070.9888
# Skipping CI.USC
# Skipping CI.AGO
# Skipping CI.DJJB
# Skipping CI.PASC
# No GOOD SKIP
# COOL Go ahead
# DJJ_CI_HH_2010-01-04T21:25:00.008800Z
# REF TIME:336334.9788
# Skipping CI.WSS
# Skipping CI.DJJB
# Skipping CI.PASC
# COOL Go ahead
# DJJ_CI_HH_2010-01-04T21:28:30.008800Z
# REF TIME:336512.4088
# Skipping CI.DEC
# Skipping CI.SMS
# Skipping CI.BLC
# Skipping CI.LCG
# Skipping CI.DJJB
# COOL Go ahead
# DJJ_CI_HH_2010-01-05T04:48:30.008800Z
# REF TIME:362938.0888
# Skipping CI.WNS
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.SMF
# Skipping CI.BLC
# Skipping CI.LFP
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.SPF
# COOL Go ahead
# DJJ_CI_HH_2010-01-05T04:49:00.008800Z
# REF TIME:362941.8888
# Skipping CI.WNS
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.SMF
# Skipping CI.BLC
# Skipping CI.LFP
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.SPF
# COOL Go ahead
# DJJ_CI_HH_2010-01-05T04:49:30.008800Z
# REF TIME:363013.2588
# Skipping CI.WNS
# Skipping CI.WSS
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.BLC
# Skipping CI.LFP
# Skipping CI.LCG
# Skipping CI.AGO
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.SPF
# Skipping CI.HLL
# COOL Go ahead
# DJJ_CI_HH_2010-01-05T04:55:30.008800Z
# REF TIME:363338.1288
# Skipping CI.NOT
# Skipping CI.BLC
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.SPF
# COOL Go ahead
# DJJ_CI_HH_2010-01-05T05:14:00.008800Z
# REF TIME:364476.5988
# Skipping CI.USC
# Skipping CI.DEC
# Skipping CI.BLC
# Skipping CI.LCG
# Skipping CI.AGO
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.SPF
# COOL Go ahead
# DJJ_CI_HH_2010-01-05T14:44:00.008800Z
# REF TIME:398674.8688
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.BLC
# Skipping CI.AGO
# Skipping CI.DJJB
# COOL Go ahead
# DJJ_CI_HH_2010-01-06T06:24:00.008800Z
# REF TIME:455058.3188
# 455078.4748
# 455066.8044
# Skipping CI.PASC
# COOL Go ahead
# DJJ_CI_HH_2010-01-07T08:00:30.008800Z
# REF TIME:547259.2488
# Skipping CI.WNS
# Skipping CI.USC
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.BLC
# Skipping CI.LFP
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.SPF
# COOL Go ahead
# DJJ_CI_HH_2010-01-07T16:11:00.008800Z
# REF TIME:576665.6388
# Skipping CI.WSS
# Skipping CI.DEC
# Skipping CI.BLC
# Skipping CI.LFP
# Skipping CI.DJJB
# 576676.7983
# Skipping CI.SPF
# COOL Go ahead
# DJJ_CI_HH_2010-01-08T00:00:00.008800Z
# REF TIME:604813.0988
# Skipping CI.RIN
# Skipping CI.WSS
# Skipping CI.USC
# Skipping CI.NOT
# Skipping CI.SMF
# Skipping CI.BLC
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.RINB
# COOL Go ahead
# DJJ_CI_HH_2010-01-08T06:29:00.008800Z
# REF TIME:628170.0088
# Skipping CI.WSS
# Skipping CI.BLC
# Skipping CI.DJJB
# Skipping CI.SPF
# No GOOD SKIP
# COOL Go ahead
# DJJ_CI_HH_2010-01-11T01:30:00.008800Z
# REF TIME:869442.4388
# Skipping CI.SMS
# Search_keys Error
# Skipping CI.DJJB
# Skipping CI.SPF
# COOL Go ahead
# DJJ_CI_HH_2010-01-11T01:44:00.008800Z
# REF TIME:870261.7888
# Skipping CI.WNS
# Skipping CI.NOT
# Skipping CI.BLC
# Search_keys Error
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.SPF
# COOL Go ahead
# DJJ_CI_HH_2010-01-11T03:01:00.008800Z
# REF TIME:874889.6688
# Skipping CI.DEC
# Skipping CI.SMS
# Skipping CI.BLC
# Search_keys Error
# Skipping CI.LCG
# Skipping CI.AGO
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.SPF
# COOL Go ahead
# DJJ_CI_HH_2010-01-11T03:01:30.008800Z
# REF TIME:874892.1688
# Skipping CI.DEC
# Skipping CI.SMS
# Skipping CI.BLC
# Search_keys Error
# Skipping CI.LCG
# Skipping CI.AGO
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.SPF
# COOL Go ahead
# DJJ_CI_HH_2010-01-11T11:12:30.008800Z
# REF TIME:904366.7088
# Skipping CI.WNS
# Skipping CI.USC
# Skipping CI.DEC
# Skipping CI.SMS
# Search_keys Error
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.PASC
# COOL Go ahead
# DJJ_CI_HH_2010-01-11T22:01:00.008800Z
# REF TIME:943268.8388
# Skipping CI.DEC
# Skipping CI.SMS
# Skipping CI.BLC
# Search_keys Error
# Skipping CI.LCG
# Skipping CI.AGO
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.RINB
# Skipping CI.SPF
# No GOOD SKIP
# COOL Go ahead
# DJJ_CI_HH_2010-01-11T23:34:00.008800Z
# REF TIME:948855.7688
# Skipping CI.WNS
# Skipping CI.WSS
# Skipping CI.USC
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.SMF
# Skipping CI.BLC
# Search_keys Error
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.SPF
# Skipping CI.HLL
# No GOOD SKIP
# COOL Go ahead
# DJJ_CI_HH_2010-01-13T00:55:30.008800Z
# REF TIME:1040177.4088
# Skipping CI.WNS
# Skipping CI.WSS
# Skipping CI.USC
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.BLC
# Search_keys Error
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.SPF
# COOL Go ahead
# DJJ_CI_HH_2010-01-13T06:39:30.008800Z
# REF TIME:1060814.3888
# Skipping CI.SMS
# Search_keys Error
# Skipping CI.AGO
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.SPF
# No GOOD SKIP
# COOL Go ahead
# DJJ_CI_HH_2010-01-14T12:57:30.008800Z
# REF TIME:1169866.9388
# Skipping CI.WNS
# Skipping CI.USC
# Skipping CI.DEC
# Skipping CI.SMS
# Skipping CI.SMF
# Search_keys Error
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.SPF
# COOL Go ahead
# DJJ_CI_HH_2010-01-14T13:37:30.008800Z
# REF TIME:1172255.0088
# Skipping CI.WNS
# Skipping CI.WSS
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.SMF
# Skipping CI.BLC
# Search_keys Error
# Skipping CI.AGO
# Skipping CI.DJJB
# Skipping CI.PASC
# Skipping CI.SPF
# COOL Go ahead
# DJJ_CI_HH_2010-01-14T15:28:30.008800Z
# REF TIME:1178939.1788
# Skipping CI.WSS
# Skipping CI.SMS
# Skipping CI.BLC
# Search_keys Error
# Skipping CI.SPF
# On 22 of 41
# COOL Go ahead
# LFP_CI_HH_2010-01-02T00:00:00.004800Z
# REF TIME:86405.0248
# Skipping CI.WNS
# Skipping CI.SMV
# Skipping CI.DJJ
# Skipping CI.PDE
# Skipping CI.DJJB
# COOL Go ahead
# LFP_CI_HH_2010-01-02T00:00:00.004800Z
# REF TIME:86405.0248
# Skipping CI.WNS
# Skipping CI.SMV
# Skipping CI.DJJ
# Skipping CI.PDE
# Skipping CI.DJJB
# 86409.0367
# COOL Go ahead
# LFP_CI_HH_2010-01-02T14:04:30.004800Z
# REF TIME:137079.1448
# Skipping CI.WSS
# Skipping CI.NOT
# Skipping CI.DJJB
# Skipping CI.IR2
# COOL Go ahead
# LFP_CI_HH_2010-01-02T22:01:30.004800Z
# REF TIME:165692.0548
# Skipping CI.VVD
# Skipping CI.DJJB
# COOL Go ahead
# LFP_CI_HH_2010-01-03T06:49:30.004800Z
# REF TIME:197371.9648
# 197363.83
# Skipping CI.PDE
# Skipping CI.IR2
# Skipping CI.RINB
# COOL Go ahead
# LFP_CI_HH_2010-01-04T02:16:30.004800Z
# REF TIME:267395.7348
# Skipping CI.WNS
# COOL Go ahead
# LFP_CI_HH_2010-01-04T07:39:30.004800Z
# REF TIME:286783.9648
# 286783.7513
# On 23 of 41
# COOL Go ahead
# PDE_CI_HH_2010-01-01T19:06:00.008800Z
# REF TIME:68789.3188
# Skipping CI.NOT
# 68799.2848
# COOL Go ahead
# PDE_CI_HH_2010-01-01T23:10:00.008800Z
# REF TIME:83420.1188
# Skipping CI.NOT
# COOL Go ahead
# PDE_CI_HH_2010-01-02T03:15:30.008800Z
# REF TIME:98162.4988
# Skipping CI.OSI
# Skipping CI.SMV
# Skipping CI.NOT
# Skipping CI.QUG
# Skipping CI.LFP
# Skipping CI.BTP
# COOL Go ahead
# PDE_CI_HH_2010-01-02T13:57:00.008800Z
# REF TIME:136632.5588
# Skipping CI.NOT
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# PDE_CI_HH_2010-01-06T14:09:30.008800Z
# REF TIME:482977.0288
# No GOOD SKIP
# COOL Go ahead
# PDE_CI_HH_2010-01-07T08:31:30.008800Z
# REF TIME:549101.0188
# Skipping CI.SMV
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# PDE_CI_HH_2010-01-08T08:18:00.008800Z
# REF TIME:634685.1088
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# PDE_CI_HH_2010-01-09T12:57:30.008800Z
# REF TIME:737855.9788
# Skipping CI.IR2
# No GOOD SKIP
# COOL Go ahead
# PDE_CI_HH_2010-01-11T00:00:00.008800Z
# REF TIME:864007.0088
# Skipping CI.SMV
# Skipping CI.NOT
# Skipping CI.QUG
# Search_keys Error
# Skipping CI.BTP
# COOL Go ahead
# PDE_CI_HH_2010-01-11T00:00:00.008800Z
# REF TIME:864007.0088
# Skipping CI.SMV
# Skipping CI.NOT
# Skipping CI.QUG
# Search_keys Error
# 864017.51
# Skipping CI.BTP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# PDE_CI_HH_2010-01-11T17:48:30.008800Z
# REF TIME:928116.9888
# Skipping CI.OSI
# Skipping CI.NOT
# Search_keys Error
# COOL Go ahead
# PDE_CI_HH_2010-01-12T02:36:30.008800Z
# REF TIME:959794.9988
# Skipping CI.RIN
# Skipping CI.OSI
# Skipping CI.VVD
# Skipping CI.SMV
# Skipping CI.NOT
# Skipping CI.QUG
# Skipping CI.BLC
# Search_keys Error
# Skipping CI.IR2
# Skipping CI.RINB
# Skipping CI.BTP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# PDE_CI_HH_2010-01-12T21:34:30.008800Z
# REF TIME:1028085.3288
# Skipping CI.NOT
# Search_keys Error
# Skipping CI.IR2
# Skipping CI.OAT
# COOL Go ahead
# PDE_CI_HH_2010-01-13T13:16:00.008800Z
# REF TIME:1084565.9788
# Skipping CI.SMV
# Search_keys Error
# COOL Go ahead
# PDE_CI_HH_2010-01-14T06:10:30.008800Z
# REF TIME:1145434.5288
# Search_keys Error
# COOL Go ahead
# PDE_CI_HH_2010-01-14T10:40:30.008800Z
# REF TIME:1161637.0988
# 1161644.1513
# Search_keys Error
# COOL Go ahead
# PDE_CI_HH_2010-01-14T17:20:00.008800Z
# REF TIME:1185624.2988
# Skipping CI.SMV
# Search_keys Error
# No GOOD SKIP
# On 24 of 41
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# LCG_CI_HH_2010-01-13T00:55:30.004800Z
# REF TIME:1040175.9248
# Skipping CI.WNS
# Skipping CI.USC
# Skipping CI.DEC
# Skipping CI.SMS
# Skipping CI.DJJ
# Skipping CI.DJJB
# Skipping CI.RUS
# Skipping CI.PASC
# Skipping CI.GVR
# Skipping CI.SPF
# On 25 of 41
# No GOOD SKIP
# COOL Go ahead
# MWC_CI_HH_2010-01-01T02:55:30.000700Z
# REF TIME:10539.0007
# Skipping CI.VCS
# Skipping CI.RHC
# Skipping CI.DEC
# Skipping CI.PASC
# COOL Go ahead
# MWC_CI_HH_2010-01-01T03:01:00.000700Z
# REF TIME:10885.5007
# Skipping CI.PASC
# COOL Go ahead
# MWC_CI_HH_2010-01-01T03:26:00.000700Z
# REF TIME:12364.0207
# Skipping CI.VCS
# Skipping CI.RHC
# Skipping CI.DEC
# Skipping CI.PASC
# Skipping CI.KIK
# No GOOD SKIP
# COOL Go ahead
# MWC_CI_HH_2010-01-01T20:05:30.000700Z
# REF TIME:72335.2307
# COOL Go ahead
# MWC_CI_HH_2010-01-01T22:20:00.000700Z
# REF TIME:80432.8307
# Skipping CI.DEC
# Skipping CI.PASC
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# MWC_CI_HH_2010-01-02T18:11:30.000700Z
# REF TIME:151912.4707
# COOL Go ahead
# MWC_CI_HH_2010-01-03T01:32:30.000700Z
# REF TIME:178354.2307
# Skipping CI.PASC
# Skipping CI.KIK
# COOL Go ahead
# MWC_CI_HH_2010-01-03T01:43:00.000700Z
# REF TIME:179001.8707
# Skipping CI.VCS
# Skipping CI.RHC
# Skipping CI.DEC
# Skipping CI.PASC
# COOL Go ahead
# MWC_CI_HH_2010-01-03T03:07:00.000700Z
# REF TIME:184057.5907
# Skipping CI.VCS
# Skipping CI.DEC
# Skipping CI.PASC
# Skipping CI.KIK
# COOL Go ahead
# MWC_CI_HH_2010-01-03T03:52:30.000700Z
# REF TIME:186758.1207
# 186759.8385
# Skipping CI.PASC
# Skipping CI.KIK
# COOL Go ahead
# MWC_CI_HH_2010-01-03T04:06:30.000700Z
# REF TIME:187610.0907
# Skipping CI.DEC
# Skipping CI.PASC
# COOL Go ahead
# MWC_CI_HH_2010-01-03T12:30:00.000700Z
# REF TIME:217824.5707
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# MWC_CI_HH_2010-01-03T18:16:00.000700Z
# REF TIME:238576.5507
# Skipping CI.KIK
# Skipping CI.MIK
# No GOOD SKIP
# COOL Go ahead
# MWC_CI_HH_2010-01-03T21:57:00.000700Z
# REF TIME:251837.7807
# 251850.6483
# Skipping CI.KIK
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# MWC_CI_HH_2010-01-04T02:55:00.000700Z
# REF TIME:269726.8507
# Skipping CI.VCS
# Skipping CI.RHC
# Skipping CI.DEC
# Skipping CI.PASC
# Skipping CI.GVR
# COOL Go ahead
# MWC_CI_HH_2010-01-04T04:13:00.000700Z
# REF TIME:274417.9207
# Skipping CI.VCS
# Skipping CI.RHC
# Skipping CI.DEC
# Skipping CI.PASC
# Skipping CI.KIK
# No GOOD SKIP
# COOL Go ahead
# MWC_CI_HH_2010-01-04T08:27:30.000700Z
# REF TIME:289654.0207
# Skipping CI.VCS
# Skipping CI.GSA
# Skipping CI.PASC
# Skipping CI.GVR
# No GOOD SKIP
# COOL Go ahead
# MWC_CI_HH_2010-01-04T22:37:00.000700Z
# REF TIME:340659.4207
# Skipping CI.VCS
# 340666.6483
# Skipping CI.MIK
# COOL Go ahead
# MWC_CI_HH_2010-01-05T04:08:00.000700Z
# REF TIME:360499.1807
# COOL Go ahead
# MWC_CI_HH_2010-01-05T04:45:00.000700Z
# REF TIME:362716.3107
# Skipping CI.VCS
# Skipping CI.RHC
# Skipping CI.DEC
# Skipping CI.PASC
# COOL Go ahead
# MWC_CI_HH_2010-01-05T04:48:30.000700Z
# REF TIME:362942.9107
# Skipping CI.DEC
# Skipping CI.PASC
# COOL Go ahead
# MWC_CI_HH_2010-01-05T04:50:00.000700Z
# REF TIME:363017.8507
# Skipping CI.VCS
# Skipping CI.MIKB
# Skipping CI.RHC
# Skipping CI.DEC
# Skipping CI.PASC
# Skipping CI.GVR
# Skipping CI.MIK
# Skipping CI.HLL
# COOL Go ahead
# MWC_CI_HH_2010-01-05T06:32:30.000700Z
# REF TIME:369169.7107
# Skipping CI.VCS
# Skipping CI.RHC
# Skipping CI.DEC
# Skipping CI.RUS
# Skipping CI.PASC
# Skipping CI.GVR
# COOL Go ahead
# MWC_CI_HH_2010-01-05T07:53:30.000700Z
# REF TIME:374043.7507
# Skipping CI.VCS
# Skipping CI.PASC
# COOL Go ahead
# MWC_CI_HH_2010-01-05T07:59:30.000700Z
# REF TIME:374388.3907
# COOL Go ahead
# MWC_CI_HH_2010-01-05T11:07:00.000700Z
# REF TIME:385659.8207
# Skipping CI.DEC
# COOL Go ahead
# MWC_CI_HH_2010-01-05T11:52:00.000700Z
# REF TIME:388352.5807
# Skipping CI.DEC
# Skipping CI.PASC
# Skipping CI.KIK
# COOL Go ahead
# MWC_CI_HH_2010-01-05T11:52:00.000700Z
# REF TIME:388352.5807
# Skipping CI.DEC
# Skipping CI.PASC
# Skipping CI.KIK
# COOL Go ahead
# MWC_CI_HH_2010-01-05T14:44:30.000700Z
# REF TIME:398679.6007
# COOL Go ahead
# MWC_CI_HH_2010-01-05T15:18:00.000700Z
# REF TIME:400695.3807
# Skipping CI.VCS
# Skipping CI.RHC
# Skipping CI.DEC
# Skipping CI.RUS
# Skipping CI.PASC
# Skipping CI.GVR
# COOL Go ahead
# MWC_CI_HH_2010-01-06T12:39:30.000700Z
# REF TIME:477589.2007
# COOL Go ahead
# MWC_CI_HH_2010-01-06T12:41:00.000700Z
# REF TIME:477691.9607
# Skipping CI.VCS
# Skipping CI.PASC
# Skipping CI.KIK
# COOL Go ahead
# MWC_CI_HH_2010-01-06T23:48:00.000700Z
# REF TIME:517688.9907
# Skipping CI.PASC
# COOL Go ahead
# MWC_CI_HH_2010-01-07T03:22:00.000700Z
# REF TIME:530554.3707
# Skipping CI.RHC
# Skipping CI.GVR
# No GOOD SKIP
# COOL Go ahead
# MWC_CI_HH_2010-01-07T08:00:30.000700Z
# REF TIME:547264.1907
# Skipping CI.DEC
# Skipping CI.PASC
# COOL Go ahead
# MWC_CI_HH_2010-01-08T02:36:30.000700Z
# REF TIME:614194.9907
# Skipping CI.PASC
# Skipping CI.KIK
# COOL Go ahead
# MWC_CI_HH_2010-01-08T02:56:30.000700Z
# REF TIME:615393.3607
# Skipping CI.PASC
# Skipping CI.MIK
# COOL Go ahead
# MWC_CI_HH_2010-01-08T05:21:30.000700Z
# ...
# COOL Go ahead
# OAT_CI_EH_2010-01-05T14:44:00.000200Z
# REF TIME:398671.7402
# Skipping CI.VVD
# 398666.15
# Skipping CI.NOT
# Skipping CI.BLC
# Skipping CI.AGO
# Skipping CI.IR2
# COOL Go ahead
# OAT_CI_EH_2010-01-05T14:54:00.000200Z
# REF TIME:399265.2902
# Skipping CI.VVD
# Skipping CI.SMV
# Skipping CI.NOT
# Skipping CI.BLC
# Skipping CI.PDE
# Skipping CI.IR2
# COOL Go ahead
# OAT_CI_EH_2010-01-05T14:54:00.000200Z
# REF TIME:399265.2902
# Skipping CI.VVD
# Skipping CI.SMV
# Skipping CI.NOT
# Skipping CI.BLC
# Skipping CI.PDE
# Skipping CI.IR2
# No GOOD SKIP
# COOL Go ahead
# OAT_CI_EH_2010-01-07T19:10:00.000000Z
# REF TIME:587444.34
# Skipping CI.WSS
# Skipping CI.SMV
# Skipping CI.PDE
# Skipping CI.AGO
# Skipping CI.IR2
# No GOOD SKIP
# COOL Go ahead
# OAT_CI_EH_2010-01-08T06:29:00.000000Z
# REF TIME:628169.34
# Skipping CI.WSS
# Skipping CI.VVD
# Skipping CI.BLC
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# OAT_CI_EH_2010-01-12T03:20:30.001100Z
# REF TIME:962448.2811
# Skipping CI.BLC
# Search_keys Error
# Skipping CI.IR2
# COOL Go ahead
# OAT_CI_EH_2010-01-12T03:20:30.001100Z
# REF TIME:962448.2811
# Skipping CI.BLC
# Search_keys Error
# Skipping CI.IR2
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# OAT_CI_EH_2010-01-14T09:38:30.001300Z
# REF TIME:1157927.1913
# Skipping CI.BLC
# Search_keys Error
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# On 34 of 41
# No GOOD SKIP
# On 35 of 41
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# On 36 of 41
# COOL Go ahead
# SPF_CI_HH_2010-01-01T10:47:30.000400Z
# REF TIME:38883.1804
# Skipping CI.SMV
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.DJJ
# Skipping CI.DJJB
# COOL Go ahead
# SPF_CI_HH_2010-01-01T22:20:00.000400Z
# REF TIME:80429.2704
# Skipping CI.SMS
# Skipping CI.DJJ
# Skipping CI.DJJB
# No GOOD SKIP
# COOL Go ahead
# SPF_CI_HH_2010-01-02T20:53:30.000400Z
# REF TIME:161619.5204
# Skipping CI.SMV
# Skipping CI.DJJ
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.RINB
# No GOOD SKIP
# COOL Go ahead
# SPF_CI_HH_2010-01-04T15:45:00.000400Z
# REF TIME:315907.9804
# Skipping CI.WNS
# Skipping CI.NOT
# 315951.1213
# Skipping CI.LCG
# Skipping CI.AGO
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# SPF_CI_HH_2010-01-05T04:48:30.000400Z
# REF TIME:362937.3904
# Skipping CI.WNS
# Skipping CI.SMV
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.SMF
# Skipping CI.BLC
# Skipping CI.DJJ
# Skipping CI.DJJB
# COOL Go ahead
# SPF_CI_HH_2010-01-05T04:49:30.000400Z
# REF TIME:363012.5604
# Skipping CI.WNS
# Skipping CI.WSS
# Skipping CI.SMV
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.BLC
# Skipping CI.DJJ
# Skipping CI.LCG
# Skipping CI.AGO
# Skipping CI.DJJB
# Skipping CI.HLL
# COOL Go ahead
# SPF_CI_HH_2010-01-05T04:55:30.000400Z
# REF TIME:363337.4504
# Skipping CI.NOT
# Skipping CI.BLC
# Skipping CI.DJJ
# Skipping CI.DJJB
# COOL Go ahead
# SPF_CI_HH_2010-01-05T05:14:00.000400Z
# REF TIME:364475.8804
# Skipping CI.BLC
# Skipping CI.DJJ
# Skipping CI.LCG
# Skipping CI.AGO
# Skipping CI.DJJB
# COOL Go ahead
# SPF_CI_HH_2010-01-05T07:31:00.000400Z
# REF TIME:372667.9404
# Skipping CI.SMV
# Skipping CI.DJJ
# Skipping CI.DJJB
# COOL Go ahead
# SPF_CI_HH_2010-01-05T07:53:30.000400Z
# REF TIME:374038.3204
# Skipping CI.SMV
# Skipping CI.NOT
# Skipping CI.BLC
# Skipping CI.DJJ
# Skipping CI.AGO
# Skipping CI.DJJB
# COOL Go ahead
# SPF_CI_HH_2010-01-05T07:59:00.000400Z
# REF TIME:374382.8504
# Skipping CI.WNS
# Skipping CI.RIN
# Skipping CI.SMV
# Skipping CI.BLC
# Skipping CI.DJJ
# Skipping CI.AGO
# Skipping CI.DJJB
# Skipping CI.RINB
# COOL Go ahead
# SPF_CI_HH_2010-01-06T00:00:00.000400Z
# REF TIME:432006.1604
# Skipping CI.WNS
# Skipping CI.RIN
# Skipping CI.LCG
# Skipping CI.DJJB
# Skipping CI.RINB
# COOL Go ahead
# SPF_CI_HH_2010-01-06T00:12:30.000400Z
# REF TIME:432752.0904
# Skipping CI.WNS
# No GOOD SKIP
# COOL Go ahead
# SPF_CI_HH_2010-01-06T21:09:00.000400Z
# REF TIME:508147.9804
# Skipping CI.SMS
# Skipping CI.AGO
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# SPF_CI_HH_2010-01-07T08:00:30.000400Z
# REF TIME:547260.7004
# Skipping CI.WNS
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.BLC
# Skipping CI.DJJ
# Skipping CI.LCG
# Skipping CI.DJJB
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# SPF_CI_HH_2010-01-07T22:05:00.000400Z
# REF TIME:597928.3204
# Skipping CI.WNS
# Skipping CI.RIN
# Skipping CI.SMV
# Skipping CI.LCG
# Skipping CI.DJJB
# No GOOD SKIP
# COOL Go ahead
# SPF_CI_HH_2010-01-08T02:36:30.000400Z
# REF TIME:614195.9604
# Skipping CI.NOT
# Skipping CI.AGO
# COOL Go ahead
# SPF_CI_HH_2010-01-08T06:29:00.000400Z
# REF TIME:628168.0604
# Skipping CI.WSS
# Skipping CI.BLC
# Skipping CI.DJJ
# Skipping CI.DJJB
# COOL Go ahead
# SPF_CI_HH_2010-01-08T09:57:30.000400Z
# REF TIME:640654.0004
# Skipping CI.LCG
# COOL Go ahead
# SPF_CI_HH_2010-01-08T16:06:00.000400Z
# REF TIME:662765.7504
# Skipping CI.SMV
# Skipping CI.LCG
# Skipping CI.AGO
# COOL Go ahead
# SPF_CI_HH_2010-01-10T00:29:30.000400Z
# REF TIME:779377.0004
# Skipping CI.WNS
# Skipping CI.WSS
# Skipping CI.SMV
# Skipping CI.SMS
# Skipping CI.SMF
# Skipping CI.BLC
# Skipping CI.DJJ
# Skipping CI.LCG
# Skipping CI.AGO
# Skipping CI.DJJB
# Skipping CI.HLL
# No GOOD SKIP
# COOL Go ahead
# SPF_CI_HH_2010-01-10T04:59:00.000400Z
# REF TIME:795581.1504
# Skipping CI.NOT
# Skipping CI.BLC
# Skipping CI.AGO
# Skipping CI.DJJB
# COOL Go ahead
# SPF_CI_HH_2010-01-10T08:05:30.000400Z
# REF TIME:806738.8204
# Skipping CI.BLC
# 806742.1546
# COOL Go ahead
# SPF_CI_HH_2010-01-10T16:08:00.000400Z
# REF TIME:835689.0004
# Skipping CI.WNS
# Skipping CI.LCG
# No GOOD SKIP
# COOL Go ahead
# SPF_CI_HH_2010-01-11T01:44:00.000400Z
# REF TIME:870259.2604
# Skipping CI.WNS
# Skipping CI.NOT
# Skipping CI.BLC
# Skipping CI.DJJ
# Skipping CI.LCG
# Skipping CI.DJJB
# COOL Go ahead
# SPF_CI_HH_2010-01-11T03:01:00.000400Z
# REF TIME:874888.3004
# Skipping CI.SMV
# Skipping CI.SMS
# Skipping CI.BLC
# Skipping CI.DJJ
# Skipping CI.LCG
# Skipping CI.AGO
# Skipping CI.DJJB
# COOL Go ahead
# SPF_CI_HH_2010-01-11T15:08:30.000400Z
# REF TIME:918517.9804
# 918526.1465
# Skipping CI.SMV
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# SPF_CI_HH_2010-01-12T02:36:30.000600Z
# REF TIME:959794.0006
# Skipping CI.WNS
# Skipping CI.RIN
# Skipping CI.WSS
# Skipping CI.SMV
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.BLC
# Skipping CI.DJJ
# Skipping CI.LCG
# Skipping CI.AGO
# Skipping CI.DJJB
# Skipping CI.RINB
# Skipping CI.HLL
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# SPF_CI_HH_2010-01-12T23:01:30.000600Z
# REF TIME:1033317.6506
# 1033314.8765
# Skipping CI.BLC
# COOL Go ahead
# SPF_CI_HH_2010-01-13T00:56:00.000400Z
# REF TIME:1040179.1104
# Skipping CI.WNS
# Skipping CI.WSS
# Skipping CI.SMV
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.BLC
# Skipping CI.DJJ
# Skipping CI.LCG
# Skipping CI.DJJB
# No GOOD SKIP
# COOL Go ahead
# SPF_CI_HH_2010-01-13T17:49:30.000400Z
# REF TIME:1100978.6704
# Skipping CI.SMS
# COOL Go ahead
# SPF_CI_HH_2010-01-13T19:30:00.000400Z
# REF TIME:1107033.5904
# Skipping CI.SMV
# Skipping CI.SMS
# COOL Go ahead
# SPF_CI_HH_2010-01-13T19:30:00.000400Z
# REF TIME:1107033.5904
# Skipping CI.SMV
# Skipping CI.SMS
# No GOOD SKIP
# COOL Go ahead
# SPF_CI_HH_2010-01-13T23:35:30.000400Z
# REF TIME:1121736.8204
# Skipping CI.BLC
# Skipping CI.LCG
# COOL Go ahead
# SPF_CI_HH_2010-01-14T09:57:30.000400Z
# REF TIME:1159062.4304
# Skipping CI.WNS
# Skipping CI.WSS
# Skipping CI.SMS
# Skipping CI.BLC
# Skipping CI.DJJ
# Skipping CI.LCG
# Skipping CI.AGO
# Skipping CI.DJJB
# COOL Go ahead
# SPF_CI_HH_2010-01-14T13:37:00.000400Z
# REF TIME:1172256.2904
# Skipping CI.WNS
# Skipping CI.WSS
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.SMF
# Skipping CI.BLC
# Skipping CI.DJJ
# Skipping CI.AGO
# Skipping CI.DJJB
# COOL Go ahead
# SPF_CI_HH_2010-01-14T15:28:30.000400Z
# REF TIME:1178939.6004
# Skipping CI.WSS
# Skipping CI.SMS
# Skipping CI.BLC
# Skipping CI.DJJ
# 1178942.2744
# On 37 of 41
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# STT_CI_EH_2010-01-01T01:16:30.000000Z
# REF TIME:4616.03
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# STT_CI_EH_2010-01-01T01:46:30.000000Z
# REF TIME:6405.96
# Skipping CI.BTP
# COOL Go ahead
# STT_CI_EH_2010-01-01T01:46:30.000000Z
# REF TIME:6405.96
# Skipping CI.BTP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# STT_CI_EH_2010-01-01T20:51:30.000000Z
# REF TIME:75141.02
# Skipping CI.BTP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# STT_CI_EH_2010-01-02T19:41:00.001100Z
# REF TIME:157306.3111
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# STT_CI_EH_2010-01-04T00:03:00.006200Z
# REF TIME:259387.0362
# Skipping CI.ALP
# Skipping CI.LEO
# Skipping CI.QAL
# Skipping CI.BTP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# STT_CI_EH_2010-01-04T22:13:00.006200Z
# REF TIME:339191.8262
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# STT_CI_EH_2010-01-05T19:22:00.000000Z
# REF TIME:415333.1
# Skipping CI.ALP
# COOL Go ahead
# STT_CI_EH_2010-01-05T19:29:30.000000Z
# REF TIME:415808.18
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# STT_CI_EH_2010-01-08T22:43:30.000000Z
# REF TIME:686659.36
# Skipping CI.LEO
# Skipping CI.BTP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# STT_CI_EH_2010-01-11T01:02:00.009900Z
# REF TIME:867730.8799
# Skipping CI.LEO
# Skipping CI.QAL
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# STT_CI_EH_2010-01-11T22:54:00.009900Z
# REF TIME:946497.7899
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# STT_CI_EH_2010-01-12T20:34:00.000000Z
# REF TIME:1024464.13
# Skipping CI.QAL
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# STT_CI_EH_2010-01-13T00:23:30.000200Z
# REF TIME:1038260.1302
# Skipping CI.QAL
# COOL Go ahead
# STT_CI_EH_2010-01-13T02:57:30.000200Z
# REF TIME:1047481.7202
# Skipping CI.QAL
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# STT_CI_EH_2010-01-13T23:01:00.000200Z
# REF TIME:1119683.3202
# Skipping CI.QAL
# Skipping CI.BTP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# STT_CI_EH_2010-01-13T23:58:00.000200Z
# REF TIME:1123086.8902
# Skipping CI.ALP
# Skipping CI.LEO
# Skipping CI.QAL
# COOL Go ahead
# STT_CI_EH_2010-01-13T23:58:00.000200Z
# REF TIME:1123086.8902
# Skipping CI.ALP
# Skipping CI.LEO
# Skipping CI.QAL
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# STT_CI_EH_2010-01-14T04:03:30.000000Z
# REF TIME:1137866.02
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# On 38 of 41
# COOL Go ahead
# BTP_CI_HH_2010-01-02T03:16:00.004800Z
# REF TIME:98166.1048
# Skipping CI.ALP
# Skipping CI.LEO
# Skipping CI.OSI
# Skipping CI.PDE
# Skipping CI.QAL
# Skipping CI.STT
# COOL Go ahead
# BTP_CI_HH_2010-01-04T00:03:00.004800Z
# REF TIME:259385.0248
# Skipping CI.ALP
# Skipping CI.LEO
# Skipping CI.OSI
# Skipping CI.VVD
# Skipping CI.PDE
# Skipping CI.QAL
# Skipping CI.STT
# No GOOD SKIP
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# BTP_CI_HH_2010-01-05T04:49:30.004800Z
# REF TIME:363015.3948
# Skipping CI.ALP
# Skipping CI.LEO
# Skipping CI.VVD
# Skipping CI.PDE
# Skipping CI.QAL
# 363021.18
# No GOOD SKIP
# COOL Go ahead
# BTP_CI_HH_2010-01-07T18:10:30.004800Z
# REF TIME:583835.0048
# Skipping CI.LEO
# Skipping CI.QAL
# COOL Go ahead
# BTP_CI_HH_2010-01-07T18:51:30.004800Z
# REF TIME:586312.9048
# Skipping CI.ALP
# Skipping CI.LEO
# Skipping CI.OSI
# Skipping CI.QAL
# No GOOD SKIP
# COOL Go ahead
# BTP_CI_HH_2010-01-10T04:59:30.004800Z
# REF TIME:795580.3148
# Skipping CI.LEO
# Skipping CI.OSI
# Skipping CI.VVD
# Skipping CI.PDE
# COOL Go ahead
# BTP_CI_HH_2010-01-10T06:34:00.004800Z
# REF TIME:801245.0448
# Skipping CI.LEO
# Skipping CI.OSI
# Skipping CI.VVD
# Skipping CI.QAL
# Skipping CI.STT
# COOL Go ahead
# BTP_CI_HH_2010-01-10T09:45:00.004800Z
# REF TIME:812739.4548
# Skipping CI.LEO
# Skipping CI.OSI
# Skipping CI.PDE
# Skipping CI.QAL
# Skipping CI.STT
# COOL Go ahead
# BTP_CI_HH_2010-01-10T16:08:00.004800Z
# REF TIME:835687.0048
# Skipping CI.OSI
# 835721.1413
# Skipping CI.PDE
# Skipping CI.QAL
# COOL Go ahead
# BTP_CI_HH_2010-01-11T23:34:00.004800Z
# REF TIME:948860.5048
# Skipping CI.ALP
# Skipping CI.LEO
# Skipping CI.OSI
# Skipping CI.VVD
# Skipping CI.QAL
# Skipping CI.STT
# No GOOD SKIP
# COOL Go ahead
# BTP_CI_HH_2010-01-12T02:36:30.004800Z
# REF TIME:959796.0048
# Skipping CI.ALP
# Skipping CI.LEO
# Skipping CI.OSI
# Skipping CI.VVD
# Skipping CI.PDE
# Skipping CI.QAL
# Skipping CI.STT
# COOL Go ahead
# BTP_CI_HH_2010-01-14T12:10:30.004800Z
# REF TIME:1167034.1848
# Skipping CI.ALP
# Skipping CI.LEO
# Skipping CI.OSI
# Skipping CI.VVD
# Skipping CI.PDE
# Skipping CI.QAL
# Skipping CI.STT
# On 39 of 41
# COOL Go ahead
# MIK_CI_HN_2010-01-08T23:38:30.004400Z
# REF TIME:689943.8044
# Skipping CI.RHC
# No GOOD SKIP
# COOL Go ahead
# MIK_CI_HN_2010-01-11T16:14:00.004400Z
# REF TIME:922445.7444
# COOL Go ahead
# MIK_CI_HN_2010-01-11T21:35:30.004400Z
# REF TIME:941777.7944
# Skipping CI.USC
# No GOOD SKIP
# COOL Go ahead
# MIK_CI_HN_2010-01-12T01:00:30.004400Z
# REF TIME:954060.1044
# No GOOD SKIP
# No GOOD SKIP
# COOL Go ahead
# MIK_CI_HN_2010-01-12T21:59:00.004400Z
# REF TIME:1029561.0944
# On 40 of 41
# COOL Go ahead
# HLL_CI_HH_2010-01-12T02:36:00.006700Z
# REF TIME:959790.7567
# Skipping CI.GSA
# Skipping CI.WNS
# Skipping CI.RIN
# Skipping CI.MIKB
# Skipping CI.WSS
# Skipping CI.USC
# Skipping CI.DEC
# Skipping CI.NOT
# Skipping CI.SMS
# Skipping CI.CBC
# Skipping CI.QUG
# Skipping CI.BLC
# Skipping CI.DJJ
# Search_keys Error
# Skipping CI.LCG
# Skipping CI.MWC
# Skipping CI.DJJB
# Skipping CI.IR2
# Skipping CI.RUS
# Skipping CI.PASC
# Skipping CI.KIK
# Skipping CI.RINB
# Skipping CI.GVR
# Skipping CI.SPF
# Skipping CI.MIK
# On 41 of 41

# %%
np.save('seqt_KLTG_1116_S.npy',s_eqt_dict)

# %%
for sta_key in s_eqt_dict.keys():
    cur_file = '/mnt/BYEB/LA_JAN/LA_DATA/PostProcess/SEQTRes/20100101/{}.S.txt'.format(sta_key)
    f = open(cur_file,'w')
    arrival_dx = 0
    pre_arrival = -1
    for arrival in s_eqt_dict[sta_key]['S']:
        if arrival_dx == 0:
            pre_arrival = arrival
            arrival_dx += 1
        else:
            if np.abs(pre_arrival - arrival) < 1:
                continue
            else:
                pre_arrival = arrival
                
        S_res = '{:.3f} 0.80 0.00000000'.format(arrival)
        f.write(S_res+'\n')
    f.close()

# %%
for sta_key in s_eqt_dict.keys():
    cur_file = '/home/Public/SiameseEQTransformer/notebooks/XJ_Events/REAL_SEQT_619-621/{}.S.txt'.format(sta_key)
    f = open(cur_file,'w')
    for arrival in s_eqt_dict[sta_key]['S']:
        S_res = '{:.3f} 0.90 0.00000000'.format(arrival)
        f.write(S_res+'\n')
    f.close()

# %%
# test 10
plot_dx = 0
sta_search_dx = 0
plot_num = 0
for sta in station_list:
    sta_search_dx += 1
    print('On {} of {}'.format(sta_search_dx, len(station_list)))
    # select stations to search
    search_list = get_search_station_list(sta, station_list, max_search_distance)
    seed_csv = '/run/media/root/Backup Plus/XJ2SEQT/{}_detections/{}_outputs/X_prediction_results.csv'.format(time_label,sta[1][3:])
    seed_csv_file = pd.read_csv(seed_csv)
    for e_time in seed_csv_file['file_name']:
        mask = (seed_csv_file['file_name'] == e_time)
        try:
            spt_t = obspy.UTCDateTime(seed_csv_file[mask]['p_arrival_time'].values[0]) - obspy.UTCDateTime(e_time[-27:])
            sst_t = obspy.UTCDateTime(seed_csv_file[mask]['s_arrival_time'].values[0]) - obspy.UTCDateTime(e_time[-27:])
            spt_prob = seed_csv_file[mask]['p_probability'].values[0]
            sst_prob = seed_csv_file[mask]['s_probability'].values[0]
        except:
            continue
        if spt_prob < 0.6:
            continue
        spt = np.zeros([1,1])
        spt[0,0] = float(spt_t/60.0)
        sst = np.zeros([1,1])
        sst[0,0] = float(sst_t/60.0)
        coda_end = np.zeros([1,1])
        coda_end[0,0] = float(sst_t/60.0)
        print(e_time)
        ref_pick_time = obspy.UTCDateTime(e_time[-27:]) + sst[0,0] * 60 - obspy.UTCDateTime(2018,6,19)
        
        
        
        seed_h5file = h5py_base_dir + '{}.hdf5'.format(sta[1][3:])
        with h5py.File(seed_h5file,'r') as f:
            dataset = f.get('data/'+e_time)
            data_t = np.array(dataset)
            data_t -= np.mean(data_t, axis=0 ,keepdims=True)
            t_std = np.std(data_t, axis = 0, keepdims=True)
            t_std[t_std == 0] = 1.0
            data_t /= t_std
            data_t -= np.mean(data_t, axis=0 ,keepdims=True)
            data_t_in = np.zeros([1,6000,3])
            data_t_in[0,:,:] = data_t
            
        for search_sta in search_list:
            # check if pick exists 
            #print(search_sta)
            search_ref_picks = s_eqt_dict[search_sta[1]]['S'] 
            if len(search_ref_picks) > 1:
                ref_key_id = bisect.bisect_left(search_ref_picks,ref_pick_time)
                try:
                    ref_left = np.abs(search_ref_picks[ref_key_id-1] - ref_pick_time)
                    ref_middle = np.abs(search_ref_picks[ref_key_id] - ref_pick_time)
                    ref_right = np.abs(search_ref_picks[ref_key_id+1] - ref_pick_time)
                    if ref_left < 6.0 or ref_middle < 6.0 or ref_right < 6.0:
                        print('Skipping {}'.format(search_sta[1]))
                        continue
                except:
                    pass
            else:
                pass
            
            search_csvfile = h5py_base_dir + '{}.csv'.format(search_sta[1][3:])
            search_csvfile = pd.read_csv(search_csvfile)
            keys = list(search_csvfile['trace_name'])
            prefix = keys[0][:-27]
            keys = [key[-27:] for key in keys]
            key_id = bisect.bisect_left(keys,e_time[-27:])
            
            try:
                search_keys = [keys[key_id-2],keys[key_id-1],keys[key_id],keys[key_id+1],keys[key_id+2]]
            except:
                continue
            # calculate key search range

            search_h5file =  h5py_base_dir + '{}.hdf5'.format(search_sta[1][3:])
            t_update_list = list()
            t_update_list_prob = list()
            with h5py.File(search_h5file,'r') as f:
                max_pred_amp = 0
                for search_key in search_keys:

                    t_search_key = prefix + search_key
                    dataset = f.get('data/'+t_search_key)
                    data_s = np.array(dataset)
                    data_s -= np.mean(data_s, axis=0 ,keepdims=True)
                    t_std = np.std(data_s, axis = 0, keepdims=True)
                    t_std[t_std == 0] = 1.0
                    data_s /= t_std

                    data_s_in = np.zeros([1,6000,3])
                    data_s_in[0,:,:] = data_s

                    encoded_t = encode_model.predict(data_t_in)
                    encoded_s = encode_model.predict(data_s_in)

                    siamese_input_list = list()

                    for rdx in range(len(RSRN_lengths)):
                        temp_length = float(RSRN_lengths[rdx])
                        template_s = int(spt[0,0]*temp_length) - 1
                        template_e = int(coda_end[0,0]*temp_length) + 1
                        template_w = int(template_e - template_s)
                        encoded_t[rdx] = encoded_t[rdx][:,template_s:template_e,:]/float(template_w)
                        encoded_t[rdx] = encoded_t[rdx].reshape([1,template_w,1,int(RSRN_channels[rdx])])
                        encoded_s[rdx] = encoded_s[rdx].reshape([1,int(RSRN_lengths[rdx]),1,int(RSRN_channels[rdx])])

                        # channel normalization
                        for channel_dx in range(int(RSRN_channels[rdx])):
                            encoded_s[rdx][0,:,0,channel_dx] -= np.max(encoded_s[rdx][0,:,0,channel_dx])
                            half_window_len = int( 200.0*temp_length/6000.0   ) + 1
                            #window_mean = np.mean(encoded_s[rdx][0,half_window_len:-half_window_len,0,channel_dx])

                            encoded_s[rdx][0,:half_window_len,0,channel_dx] = encoded_s[rdx][0,half_window_len,0,channel_dx]
                            encoded_s[rdx][0,-half_window_len:,0,channel_dx] =  encoded_s[rdx][0,-half_window_len,0,channel_dx]

                            encoded_s[rdx][0,:,0,channel_dx] *= -1.0
                            encoded_s[rdx][0,:,0,channel_dx] -= np.mean(encoded_s[rdx][0,:,0,channel_dx])
                            t_max = np.max(np.abs(encoded_s[rdx][0,:,0,channel_dx]))
                            if t_max < 0.01:
                                t_max = 1
                            encoded_s[rdx][0,:,0,channel_dx] /= t_max

                            encoded_t[rdx][0,:,0,channel_dx] -= np.max(encoded_t[rdx][0,:,0,channel_dx])
                            encoded_t[rdx][0,:,0,channel_dx] *= -1.0
                            encoded_t[rdx][0,:,0,channel_dx] -= np.mean(encoded_t[rdx][0,:,0,channel_dx])
                            t_max = np.max(np.abs(encoded_t[rdx][0,:,0,channel_dx]))
                            if t_max < 0.01:
                                t_max = 1
                            encoded_t[rdx][0,:,0,channel_dx] /= t_max

                        siamese_input_list.append(encoded_t[rdx])
                        siamese_input_list.append(encoded_s[rdx])

                    #print('RSRN Channel_normal OK')
                    if if_encoder_concate == 1:
                        for rdx in range(len(RSRN_lengths), len(RSRN_lengths) + len(encoder_encoded_list)):
                            rdx_2 = rdx - len(RSRN_lengths) 
                            temp_length = float(encoder_encoded_lengths[rdx_2])
                            template_s = int(spt[0,0]*temp_length) - 1
                            template_e = int(coda_end[0,0]*temp_length) + 1
                            template_w = int(template_e - template_s)
                            #print('Concate 1 OK')
                            encoded_t[rdx] = encoded_t[rdx][:,template_s:template_e,:]/float(template_w)
                            encoded_t[rdx] = encoded_t[rdx].reshape([1,template_w,1,int(encoder_encoded_channels[rdx_2])])
                            encoded_s[rdx] = encoded_s[rdx].reshape([1,int(encoder_encoded_lengths[rdx_2]),1,int(encoder_encoded_channels[rdx_2])])
                            #print('Concate 2 OK')
                            # channel normalization
                            for channel_dx in range(int(encoder_encoded_channels[rdx_2])):
                                encoded_s[rdx][0,:,0,channel_dx] -= np.max(encoded_s[rdx][0,:,0,channel_dx])
                                half_window_len = int( 200.0*temp_length/6000.0   ) + 1
                                #window_mean = np.mean(encoded_s[rdx][0,half_window_len:-half_window_len,0,channel_dx])
                                #print('Concate 3 OK')
                                encoded_s[rdx][0,:half_window_len,0,channel_dx] = encoded_s[rdx][0,half_window_len,0,channel_dx]
                                encoded_s[rdx][0,-half_window_len:,0,channel_dx] =  encoded_s[rdx][0,-half_window_len,0,channel_dx]
                                #print('Concate 4 OK')
                                encoded_s[rdx][0,:,0,channel_dx] *= -1.0
                                encoded_s[rdx][0,:,0,channel_dx] -= np.mean(encoded_s[rdx][0,:,0,channel_dx])
                                t_max = np.max(np.abs(encoded_s[rdx][0,:,0,channel_dx]))
                                if t_max < 0.01:
                                    t_max = 1
                                encoded_s[rdx][0,:,0,channel_dx] /= t_max
                                #print('Concate 5 OK')
                                encoded_t[rdx][0,:,0,channel_dx] -= np.max(encoded_t[rdx][0,:,0,channel_dx])
                                encoded_t[rdx][0,:,0,channel_dx] *= -1.0
                                encoded_t[rdx][0,:,0,channel_dx] -= np.mean(encoded_t[rdx][0,:,0,channel_dx])
                                t_max = np.max(np.abs(encoded_t[rdx][0,:,0,channel_dx]))
                                if t_max < 0.01:
                                    t_max = 1
                                encoded_t[rdx][0,:,0,channel_dx] /= t_max
                                #print('Concate 6 OK')
                            siamese_input_list.append(encoded_t[rdx])
                            siamese_input_list.append(encoded_s[rdx])
                    pred_res = siamese_model.predict(siamese_input_list)
                    siamese_s = np.argmax(pred_res[-1][0,:,0,0])
                    pred_amp = pred_res[-1][0,siamese_s,0,0]
                    
                    if pred_amp > 0.3 and siamese_s > 200 and siamese_s < 5800:
                        siamese_s_time = obspy.UTCDateTime(search_key) + siamese_s * 0.01
                        t_update_time  = siamese_s_time - base_time
                        t_diff_time = siamese_s_time - (obspy.UTCDateTime(e_time[-27:]) + sst[0,0] * 60)
                        #r_snr = np.max(np.abs(data_s_in[0,siamese_s-50:siamese_s,0]))/np.max(np.abs(data_s_in[0,siamese_s:siamese_s+100,0]))
                        
                        if np.abs(t_diff_time) < 8:
                            pass
                        else:
                            print(t_diff_time)
                            continue

                        max_pred_amp = pred_amp
                        s_pred_amp = pred_amp
                        siamese_s_time = obspy.UTCDateTime(search_key) + siamese_s * 0.01
                        t_update_time  = siamese_s_time - base_time
                        plot_data_s = data_s_in
                        
                        #print(max_pred_amp)
                        #print(siamese_s_time)
                        #print(obspy.UTCDateTime(e_time[-27:]) + sst[0,0] * 60)


                        eqt_res = EqT_model.predict(plot_data_s)
                        eqt_s = np.argmax(eqt_res[2][0,:,0])
                        pred_amp = eqt_res[2][0,eqt_s,0]
                        if pred_amp > 0.1:
                            pass
                        else:
                            eqt_s = 0.0

                        plt.figure(figsize=(20,16))
                        pdx = 0
                        plt.plot(data_t_in[0,:,0]+pdx*20,color='k')
                        plt.plot(data_t_in[0,:,1]+pdx*20+4,color='k')
                        plt.plot(data_t_in[0,:,2]+pdx*20+8,color='k')
                        plt.plot([sst_t*100,sst_t*100],[pdx*20-10,pdx*20+10],color='g',linewidth=3)

                        pdx = 1
                        plt.plot(plot_data_s[0,:,0]+pdx*20,color='k')
                        plt.plot(plot_data_s[0,:,1]+pdx*20+4,color='k')
                        plt.plot(plot_data_s[0,:,2]+pdx*20+8,color='k')

                        plt.plot([eqt_s,eqt_s],[pdx*20-10,pdx*20+10],color='g',linewidth=3)

                        plt.plot([siamese_s,siamese_s],[pdx*20-7,pdx*20+7],color='r',linewidth=2)
                        plt.title('{}'.format(s_pred_amp),fontsize=30)
                        plt.savefig('t_figs/S_CHECK_{}_{}_{}.png'.format(sta[1][3:],search_sta[1][3:],plot_dx))
                        plot_dx += 1
                        plot_num += 1
                        plt.close()
            
                        t_update_list.append(t_update_time)
                        t_update_list_prob.append(pred_amp)
                if len(t_update_list) > 0:
                    max_arg = np.argmax(t_update_list_prob)
                    t_update_time = t_update_list[max_arg]
                    bisect.insort(s_eqt_dict[search_sta[1]]['S'], t_update_time)
                    print('{}'.format(t_update_time))
                    
            if plot_num > 10:
                break
        if plot_num > 10:
            break
    if plot_num > 10:
        break
                           
    """
    plt.figure(figsize=(6,6))
    plt.scatter(sta[3],sta[2],color='r')
    for t_sta in search_list:
        plt.scatter(t_sta[3],t_sta[2],color='b')
    plt.xlim([-118.8,-118.0])
    plt.ylim([34.0,34.8])
    plt.show()
    plt.close()
    """
    # open search list csv and hdf5 file
    # for all high P
    #     for all search stations
    #        for all time within range
    #           calcualte P
    #           keep highest Prob
    #           check insert Point
    #

# %%
len(s_eqt_dict.keys())
# Out:
# 41

# %%
for sta_key in s_eqt_dict.keys():
    s_times = s_eqt_dict[sta_key]['S']
    savefile = open('/mnt/BYEB/LA_JAN/LA_DATA/PostProcess/SEQTRes/20100101/{}.S.txt'.format(sta_key),'w')
    for s_t in s_times:
        savefile.write('{:.3f} 0.80000 0.00000000\n'.format(s_t))
    savefile.close()
# Out:
# [10554.053, 98182.773, 331719.003, 331924.823, 363024.3927, 586317.2127, 683953.173, 827337.2827, 923929.493, 935598.623, 948284.173, 948875.863, 959811.763, 1003383.563, 1040201.7527, 1110698.903, 1120453.533, 1152948.5527, 1167049.823, 1169877.093, 1192038.433, 1192066.193, 1200155.233, 1200905.763, 1201704.613, 1201790.903]
# [10557.441, 12380.8707, 98180.121, 269739.9107, 274434.8707, 331722.491, 331928.301, 340659.961, 362733.861, 363024.821, 381381.9807, 428306.491, 448451.5907, 477696.5507, 737807.621, 779382.731, 788168.771, 796220.631, 810587.5007, 827338.7207, 829394.4707, 859264.431, 900971.1207, 948276.571, 948868.441, 959804.691, 978229.4307, 984971.041, 1040191.691, 1152945.201, 1167055.921, 1169882.931, 1178955.541]
# [98173.5107, 331733.6607, 411220.721, 526445.2707, 948865.8307, 959801.741, 959801.7507]
# [16466.8848, 98168.217, 190098.0767, 267406.4807, 331735.7507, 362943.6827, 363018.753, 369167.9227, 439134.423, 521057.099, 521089.039, 522058.929, 526442.039, 526469.239, 544064.7988, 547262.3588, 591714.789, 593149.439, 595136.909, 595234.739, 600140.519, 600173.239, 603968.849, 613111.593, 743188.829, 754152.629, 763475.839, 777816.405, 796207.5148, 828340.075, 833253.305, 834569.625, 834583.985, 834592.505, 835139.115, 839148.155, 839474.665, 839483.095, 841048.465, 841764.495, 871132.118, 948855.2185, 959806.877, 1032367.457, 1040180.241, 1123210.263, 1130462.923]
# [10555.64, 12378.43, 80438.4, 98180.291, 101370.731, 115102.201, 116938.081, 137112.901, 179034.27, 224785.9, 224872.5, 235947.51, 244309.7, 247205.33, 256995.4299, 269748.8858, 274441.926, 295663.576, 313065.546, 322197.196, 328901.856, 329202.916, 331720.876, 331926.106, 334387.136, 363023.27, 364486.77, 385310.09, 499962.95, 508864.65, 539025.1, 551547.54, 583848.82, 586319.0, 614196.31, 624130.58, 628183.06, 641843.18, 658209.18, 686679.39, 694866.03, 695109.2, 708560.7, 737815.38, 759023.66, 779378.31, 795421.26, 795585.45, 796228.47, 812747.05, 827336.49, 837751.29, 859271.56, 866179.43, 894906.64, 895926.24, 897232.62, 907756.79, 915118.4, 920030.23, 920837.52, 920949.95, 935636.99, 943276.5599, 948284.19, 948876.26, 1031255.67, 1040194.57, 1046677.0, 1120317.91, 1152947.79, 1163308.28, 1169878.72, 1170211.67, 1172267.09, 1177079.64, 1178958.65]
# [375412.7448, 959812.8648]
# [98173.0344, 331732.7244, 363024.7144, 948865.804, 959801.644, 959801.6444]
# [28960.977, 190104.4865, 356503.5165, 587442.5565, 604820.5765, 628170.1565, 877395.8465, 948286.986, 948879.676, 951370.2265, 959815.027, 978221.3565, 1178946.407, 1196233.147, 1196249.617]
# [98178.414, 116933.734, 259418.944, 331727.254, 554360.214, 586317.9143, 614195.334, 728956.824, 812744.1543, 835690.354, 899598.254, 928153.524, 948884.644, 959819.234, 1099673.914, 1167056.934, 1169883.924]
# [12399.9299, 14069.19, 68270.26, 101095.42, 167813.77, 264158.77, 274428.62, 331736.52, 363026.46, 400695.68, 547271.5099, 624120.47, 796215.4399, 806603.85, 844584.7199, 868594.17, 948272.19, 948863.62, 959800.9599, 1123212.45]
# [116938.1299, 128015.46, 259416.8013, 261362.981, 356506.3102, 362939.53, 363014.5, 364477.97, 364497.01, 373750.58, 374040.39, 374385.05, 399298.2302, 403765.0302, 458657.9002, 524456.52, 614203.19, 628170.21, 795578.891, 796235.6613, 859280.5713, 877393.83, 896397.47, 902319.66, 903029.06, 903558.51, 903635.12, 943271.27, 944450.3, 948290.24, 948882.54, 959818.391, 978904.6313, 1132141.781, 1167062.631, 1186416.211, 1188027.871, 1196341.851, 1197468.431, 1205602.481]
# [98169.1383, 190093.6783, 274425.6283, 375659.708, 378760.588, 547260.3283, 604815.9983, 632348.248, 633911.7683, 735380.7183, 864008.3183, 941776.6383, 948871.2583, 959807.038, 991030.538, 995677.388, 1040178.848, 1062284.208, 1147808.128, 1147814.588, 1150582.368, 1150618.588]
# [12388.2285, 16471.1285, 80432.538, 98171.969, 165699.8385, 184061.2785, 190102.3085, 257004.0785, 331731.428, 331937.219, 336509.3585, 362939.1985, 363018.758, 364481.7585, 369168.0785, 381373.9285, 388352.7185, 544066.4785, 576663.9985, 624123.8485, 641836.5485, 691699.1985, 779383.889, 796223.4285, 801413.019, 810594.3985, 823577.378, 841045.6785, 859267.439, 864022.399, 864054.069, 874898.5285, 900977.9085, 902325.549, 948279.078, 948871.139, 959807.358, 978105.3685, 1040184.108, 1147808.6385, 1167062.829, 1169889.978, 1172278.3985, 1172278.418]
# [3980.0, 6478.82, 8417.18, 9354.21, 9888.55, 10739.64, 10951.19, 15435.66, 20840.53, 23011.94, 23228.07, 24150.96, 24831.44, 30951.08, 31424.7, 32212.49, 32298.5, 33755.3, 37695.89, 38885.27, 39775.85, 42927.84, 44577.88, 46097.17, 51032.0, 56773.19, 57252.55, 62837.25, 62838.47, 67704.33, 73307.16, 84743.99, 86416.08, 88999.65, 89467.45, 93242.78, 101182.17, 109599.64, 112159.9, 113196.68, 122491.66, 124322.0, 141586.63, 142704.81, 144946.75, 147441.83, 153180.8, 154011.27, 154951.59, 161367.61, 161623.51, 165362.13, 172933.3, 173604.11, 178184.27, 181723.09, 182841.63, 186101.89, 186731.51, 187597.33, 190257.39, 192563.96, 194400.89, 204864.65, 206530.18, 223064.93, 225148.64, 230241.08, 241287.34, 242902.47, 243530.37, 246470.6, 247847.21, 248488.43, 250132.47, 259338.14, 260660.18, 266980.04, 274028.17, 279197.27, 286172.07, 290058.88, 308551.3, 310305.73, 310754.45, 312761.89, 313610.57, 324559.19, 327339.46, 329613.53, 331132.72, 331698.87, 331727.06, 338495.64, 340689.44, 342050.25, 346073.02, 352496.04, 354391.09, 356495.47, 362509.26, 363114.94, 364767.24, 367181.91, 368601.77, 371019.61, 376857.73, 377432.28, 384747.78, 391078.24, 393316.41, 397341.52, 400065.35, 400187.66, 400493.11, 402600.14, 405639.69, 407994.11, 408473.99, 414373.94, 416758.0, 420895.37, 422409.04, 426360.2, 435953.72, 447789.6, 448325.13, 456594.85, 458649.13, 460758.87, 464956.93, 467247.68, 470532.6, 471563.65, 477931.46, 487569.97, 490415.36, 492155.39, 493923.56, 494676.79, 495046.43, 499930.23, 500500.04, 502133.35, 519460.9, 520769.16, 529717.91, 533601.23, 552981.39, 553397.13, 556184.13, 578085.9, 586924.39, 587445.04, 595390.07, 597939.02, 599275.11, 605710.29, 609893.12, 614661.07, 621133.87, 646252.03, 646843.16, 672830.51, 673752.93, 674927.32, 695295.67, 696371.06, 704839.48, 712484.27, 720132.97, 753974.53, 757403.24, 769850.17, 775897.27, 775918.93, 794156.6, 794656.95, 838071.77, 845179.32, 864011.75, 922555.68, 935275.69, 935477.6, 941576.84, 945234.11, 950538.6, 951367.83, 959816.39, 963156.84, 964370.15, 964996.99, 966891.82, 973754.4, 983593.81, 987647.57, 1005348.31, 1006038.65, 1011084.85, 1021987.8, 1035860.11, 1036965.2, 1038954.34, 1040735.45, 1075371.92, 1084552.49, 1097485.33, 1115080.98, 1123327.9, 1137826.42, 1139414.82, 1161416.14, 1173895.13, 1181995.35, 1184302.31, 1188504.25, 1191991.0, 1194934.12, 1204789.24]
# [15832.12, 15865.35, 68788.21, 83423.03, 98170.32, 123733.98, 135381.94, 136038.31, 136287.22, 141346.52, 231564.06, 297299.56, 315280.68, 334906.02, 362943.42, 363011.51, 377514.54, 377720.61, 380001.05, 383398.09, 391786.92, 395896.16, 399287.35, 470635.35, 500276.61, 547260.38, 565505.22, 584618.64, 606441.45, 650110.35, 653940.73, 679128.91, 700797.03, 729016.93, 729374.47, 748200.06, 748755.45, 763478.68, 777613.69, 826797.5, 834770.68, 862827.82, 864022.21, 919243.51, 922848.44, 922886.61, 924536.3, 934278.89, 959812.47, 982084.63, 999534.99, 1000786.4, 1001494.27, 1077388.44, 1077561.94, 1096721.2, 1118837.07, 1121088.26, 1133479.33, 1136886.13, 1137308.84, 1198364.9, 1207784.36]
# [16468.0665, 38888.8665, 98164.126, 106731.757, 185767.3765, 190097.3565, 203778.816, 331741.096, 331947.1865, 336515.2765, 362944.4765, 363021.546, 457572.846, 470626.546, 470635.586, 544071.9265, 547265.4365, 606175.517, 608411.537, 633908.627, 648486.456, 648499.986, 696239.936, 869445.6765, 874890.9465, 943283.7565, 948874.907, 959810.566, 982090.267, 1040179.7565, 1040179.806, 1060815.9265]
# [151911.1, 179002.64, 233727.45, 274412.371, 275780.461, 283705.961, 313036.171, 331728.311, 331933.891, 362738.05, 519627.12, 580060.33, 624105.98, 672647.77, 691673.54, 699198.89, 737793.58, 754717.47, 796203.381, 859245.351, 922740.5, 948841.26, 1017343.891, 1067497.981, 1089226.511, 1167067.541, 1172281.831, 1178082.581, 1203265.321, 1209169.861]
# [98173.7627, 948866.1527, 959801.933, 959802.0827]
# [331730.5541, 403774.114, 458655.2741, 896397.5941, 943269.1141, 944452.9441, 948877.874, 951366.764, 959813.614, 1167060.784, 1172276.094]
# [256990.55, 336525.6013, 362936.7002, 363011.43, 363335.41, 364474.01, 364492.92, 373746.6, 374036.17, 374380.92, 399295.53, 547261.83, 576665.75, 584620.39, 628170.2, 763908.66, 796225.1313, 859269.1913, 870266.3, 874890.31, 877017.75, 877392.94, 896396.25, 902318.58, 943268.72, 944447.67, 959816.121, 978222.6313, 978896.1513, 1120311.9909, 1137319.5113, 1166233.581, 1178948.1513, 1205456.361]
# [2891.079, 10571.899, 16466.889, 22667.409, 38889.059, 80432.179, 86416.7288, 98165.209, 157538.929, 161624.2388, 185768.709, 190099.009, 231568.939, 286079.779, 331736.519, 331942.1488, 336337.519, 336514.989, 362942.449, 363017.569, 363342.529, 364480.839, 398679.129, 399301.2788, 430843.4388, 455067.109, 547261.969, 576668.289, 604821.699, 624128.5588, 628174.999, 632348.8488, 691699.9188, 735370.6288, 763485.9988, 779384.759, 796225.3588, 859270.2388, 869444.259, 870270.369, 874892.849, 902325.5188, 904370.029, 919247.2088, 943272.169, 948280.839, 948873.619, 959809.029, 1040180.719, 1060816.399, 1077385.3588, 1167068.659, 1169896.059, 1172284.189, 1178942.329]
# [86407.205, 86446.215, 98171.1148, 137088.245, 165692.855, 197372.405, 256986.0748, 267402.905, 286784.295, 331732.8048, 331732.8048, 362939.3548, 362941.1848, 381375.6748, 576666.5548]
# [68795.759, 83428.549, 86410.8088, 98174.829, 136643.259, 236536.719, 259423.6788, 340075.649, 413325.629, 419579.029, 448464.4088, 482986.429, 524698.349, 549111.169, 584615.8488, 585832.739, 587437.2088, 622943.309, 626949.179, 634689.299, 698551.719, 724575.899, 737860.649, 798467.449, 864013.279, 877011.4388, 896398.0088, 896462.969, 898337.999, 902325.4388, 923715.739, 928123.149, 944448.0788, 959816.869, 967970.099, 978885.2788, 994269.219, 1028087.469, 1084583.979, 1145451.279, 1161640.539, 1185632.519, 1197043.199]
# [1116.845, 2887.9248, 16467.5248, 98165.6048, 106721.3548, 157536.7848, 161611.4348, 185779.6748, 331724.9548, 432008.3948, 457578.8048, 470637.0448, 521051.0348, 526449.5248, 547261.4348, 591709.5148, 600149.5048, 608413.9048, 624106.9448, 869433.1448, 870269.4248, 874885.5148, 948875.2748, 959809.315, 982081.5848, 991028.7948, 1040178.625, 1147819.1248]
# [10539.561, 10564.211, 10890.681, 12388.301, 51831.401, 72335.641, 80439.181, 98175.511, 151177.621, 151921.591, 178356.531, 179020.541, 184063.881, 186770.961, 187628.751, 217829.341, 218404.611, 233743.181, 238579.521, 247604.981, 251848.291, 259205.121, 259241.521, 269736.211, 274430.351, 275786.791, 289665.561, 331729.3607, 331935.191, 340663.951, 360510.791, 362740.361, 362950.341, 363025.481, 369173.871, 374051.221, 374395.781, 385663.421, 388354.411, 398687.041, 400701.501, 477589.751, 477692.801, 517713.891, 530563.571, 544077.511, 547268.281, 614211.061, 615399.261, 624118.731, 628184.351, 628586.631, 641834.971, 644202.891, 671963.341, 672666.901, 691692.921, 699217.741, 701979.081, 717223.771, 733882.951, 737801.511, 761993.1207, 779385.081, 787072.941, 788175.791, 796216.251, 810591.591, 822600.001, 823467.991, 823496.071, 827346.701, 829397.871, 829414.841, 835727.741, 844593.791, 859260.041, 870280.291, 885884.651, 896409.541, 900499.421, 900971.591, 948260.301, 948269.661, 948864.291, 959800.221, 1040185.961, 1167063.741, 1172279.181, 1178950.351]
# [1745.45, 5367.61, 6730.26, 13770.08, 14046.82, 14445.45, 15393.6, 15709.64, 17920.68, 17973.95, 18176.57, 19661.53, 19708.25, 21216.75, 21748.99, 21907.72, 23340.71, 23402.16, 24744.53, 25289.97, 27957.72, 28672.76, 29423.54, 30343.44, 31233.32, 33194.21, 35240.31, 36938.41, 37134.29, 37258.21, 37411.7, 37521.33, 39561.87, 40585.26, 40617.09, 40974.45, 41968.2, 41990.11, 44317.2, 48244.47, 48629.61, 49775.4, 50550.17, 50606.08, 53396.56, 56236.32, 56307.95, 56543.85, 57411.18, 57553.9, 58067.46, 59094.94, 59263.0, 59815.83, 63361.39, 63775.13, 63950.02, 65173.12, 65254.31, 68305.37, 68816.67, 72828.0, 72937.05, 74897.93, 76037.09, 77968.45, 79758.74, 79769.35, 83405.28, 83625.08, 85101.71, 88640.76, 96597.91, 98008.77, 100563.81, 100683.66, 102514.32, 105744.17, 106496.73, 107066.7, 107180.47, 108930.64, 109003.88, 109357.45, 109379.54, 110419.8, 110468.69, 111679.7, 113426.87, 113664.85, 114071.59, 114858.43, 115083.96, 115107.27, 115602.58, 115817.49, 116383.58, 116398.12, 116604.69, 116925.26, 118135.55, 118808.91, 119085.5, 122289.05, 122649.06, 123187.86, 123282.19, 123885.9, 124108.59, 124342.09, 124806.6, 124845.41, 125173.75, 126363.9, 127594.2, 127636.29, 127679.59, 128754.36, 128904.14, 129677.82, 129805.41, 129930.25, 131567.27, 131712.28, 131725.85, 131933.08, 132183.23, 132865.16, 134042.89, 135028.77, 135698.29, 135718.69, 136033.24, 136482.49, 136717.06, 147796.07, 149008.11, 149954.47, 150560.23, 151545.26, 152098.81, 152393.42, 153170.31, 154090.47, 154127.16, 154833.02, 155787.19, 156320.39, 157978.25, 158905.35, 159915.12, 161357.97, 162257.55, 162700.89, 162788.16, 162838.23, 164347.6, 168569.32, 174450.38, 177444.09, 179182.02, 181781.22, 187969.57, 188675.71, 188940.8, 190096.15, 192716.83, 196485.75, 199256.01, 200689.29, 202685.67, 204743.96, 206036.7, 207569.82, 209061.18, 209273.65, 209480.87, 211533.61, 211683.9, 212047.56, 212067.79, 212255.85, 212277.9, 213755.16, 213888.57, 214506.38, 214660.15, 217069.45, 220839.74, 220855.29, 221064.14, 221085.71, 221093.6, 221118.57, 222009.01, 222194.28, 224200.31, 224323.37, 224339.66, 224837.81, 225046.14, 229088.56, 229149.42, 229480.88, 231640.57, 231738.94, 233353.84, 234643.69, 234867.26, 234896.06, 237463.96, 239153.33, 240038.63, 241905.24, 241999.33, 242061.63, 243774.49, 244617.68, 247704.03, 252376.26, 253640.46, 264838.81, 265281.87, 267221.1, 268972.13, 269250.56, 270240.1, 274942.78, 275237.17, 275736.15, 275995.14, 277451.08, 277706.11, 277750.09, 277948.89, 278857.43, 280149.2, 281135.65, 281667.26, 282110.94, 282480.45, 282633.97, 283662.09, 283830.01, 285046.83, 285171.93, 285335.93, 285955.92, 287664.92, 287711.61, 288302.67, 288503.08, 288524.15, 288776.47, 289420.87, 290269.99, 290426.55, 290946.18, 291265.48, 291834.33, 292097.74, 292619.43, 292649.59, 293396.17, 293652.96, 294470.09, 296068.89, 296151.52, 296173.79, 296460.67, 298206.9, 298828.99, 300826.9, 302232.87, 302478.42, 302518.07, 302528.25, 303029.03, 303073.07, 303221.27, 304034.44, 304176.75, 311954.7, 314064.89, 317265.01, 317779.45, 320366.12, 322687.75, 327557.85, 327690.83, 329327.89, 330374.8, 332305.75, 332392.6, 334543.01, 334972.13, 336097.75, 338241.79, 338786.1, 339603.89, 340913.94, 344006.92, 344433.95, 345401.69, 347545.15, 348077.71, 348134.67, 349527.69, 351021.22, 352535.89, 353211.23, 353695.06, 354387.2, 355909.02, 356175.19, 356213.51, 356504.41, 357511.37, 357943.97, 358137.52, 359839.86, 360282.59, 360433.82, 362087.09, 362572.45, 362660.57, 362851.28, 372590.73, 373062.56, 373331.28, 373577.43, 373995.62, 374362.67, 374528.46, 374717.73, 375971.49, 376523.75, 376725.73, 377896.29, 378332.93, 378397.96, 378603.78, 378974.27, 378990.04, 379191.81, 380518.9, 381453.96, 381539.27, 381568.56, 381853.82, 381892.88, 382641.0, 383285.62, 384172.05, 384205.41, 384941.12, 385529.5, 385618.26, 386763.75, 387707.7, 388037.2, 389030.95, 389424.09, 389693.62, 390065.21, 390080.77, 390269.83, 391293.22, 391721.59, 392206.48, 392303.82, 392368.93, 392851.7, 393475.05,  ...
# [6647.89, 68809.96, 98182.331, 116929.521, 169969.251, 176686.9, 259422.566, 331724.886, 331930.956, 363023.84, 512625.73, 512700.05, 515424.16, 517600.82, 517681.08, 518748.61, 523878.02, 580753.37, 586313.28, 592979.65, 595763.23, 596850.41, 597956.58, 600108.68, 600429.6, 601680.46, 605018.01, 605874.42, 606689.67, 614190.87, 686799.29, 687852.2, 756196.78, 777620.18, 777659.61, 779371.45, 786209.49, 788165.6, 799827.34, 812738.86, 837734.23, 864700.77, 867413.57, 867753.25, 907745.83, 944806.14, 944894.41, 946851.16, 948272.6, 948862.87, 948989.41, 952859.7, 955003.41, 955901.63, 956524.31, 956686.34, 959822.55, 1026262.49, 1030480.85, 1030691.51, 1030934.53, 1031083.03, 1031153.59, 1031638.32, 1033044.75, 1037756.34, 1037931.24, 1043002.13, 1047481.8302, 1072642.59, 1072830.77, 1074226.73, 1110608.45, 1110716.6, 1111046.71, 1111089.13, 1111968.36, 1118217.22, 1119332.62, 1119694.07, 1123651.01, 1124138.16, 1124224.68, 1126738.47, 1127516.33, 1127801.05, 1127846.23, 1127974.51, 1131445.02, 1132028.72, 1134392.83, 1134700.79, 1135437.56, 1135501.93, 1135664.63, 1135733.13, 1137622.49, 1138910.59, 1139456.26, 1140907.78, 1141097.69, 1194352.47, 1195501.47, 1203406.45]
# [2889.0246, 16466.765, 38889.185, 80432.195, 86410.5646, 98165.125, 106725.1046, 190099.124, 209050.3144, 231568.8044, 274420.9444, 331736.294, 331942.254, 336337.414, 336514.794, 362942.574, 363017.524, 364480.834, 374387.864, 374399.164, 374421.974, 398679.074, 427373.924, 430843.444, 430879.734, 526434.7144, 544072.434, 547261.884, 576668.284, 604821.5344, 628174.964, 648496.1544, 691700.5644, 761991.6044, 779379.885, 796229.6846, 844598.7246, 859270.3946, 869444.2446, 870270.295, 871134.4746, 874892.775, 904369.775, 919247.155, 934743.195, 943272.175, 948281.335, 948873.665, 959809.505, 978223.485, 1040180.624, 1060816.4044, 1137297.9144, 1167068.694, 1172267.7544, 1178942.264]
# [115109.31, 127785.38, 137115.95, 144062.77, 151930.63, 179030.93, 184073.66, 190106.48, 190139.16, 197370.41, 218413.14, 233752.08, 251857.36, 256993.29, 269745.261, 274439.511, 286918.751, 289675.631, 304961.651, 320266.511, 330045.701, 331727.981, 331933.721, 340667.131, 355101.89, 360521.22, 362739.85, 362942.67, 363017.94, 363029.65, 363342.8, 364481.07, 373753.87, 374043.63, 374388.16, 381380.13, 391018.81, 398679.33, 400709.81, 448454.58, 505859.15, 516248.94, 530572.5, 532852.01, 540221.15, 540485.23, 547262.34, 576668.67, 583436.64, 583848.51, 584621.11, 586325.93, 587445.48, 592249.99, 614202.26, 624128.04, 637644.9, 641842.97, 672676.76, 688565.75, 691702.7, 699227.49, 713006.23, 737810.84, 761995.89, 765040.25, 771498.21, 779381.821, 787081.981, 788170.641, 795582.611, 796225.611, 811338.251, 812752.921, 820778.381, 823477.171, 827342.0713, 829401.591, 859269.151, 864017.99, 870273.29, 874901.22, 877017.75, 877396.87, 896400.38, 900503.06, 902322.56, 903637.96, 920368.09, 943269.56, 944454.39, 948281.06, 948872.94, 951800.861, 958071.861, 959808.591, 978112.211, 978222.841, 978896.681, 1040188.261, 1069286.291, 1069313.901, 1120311.771, 1146672.331, 1152950.141, 1159078.081, 1163315.901, 1163381.371, 1167058.961, 1169886.171, 1172274.441, 1178950.901, 1184927.501, 1185817.161, 1186160.791, 1186814.971, 1196575.611, 1205452.481, 1205603.441, 1209185.171]
# [369170.6488, 948273.019, 948865.199, 959800.9588, 959800.989, 1040183.6788]
# [10565.088, 10893.428, 12390.058, 16470.8883, 80436.258, 98171.918, 127778.948, 137111.908, 178367.9983, 179022.608, 184065.878, 185780.3983, 190099.9983, 218407.708, 269738.5783, 274432.678, 275807.988, 304953.498, 331731.6883, 331937.498, 336338.6483, 362947.108, 363022.258, 364483.5183, 369170.788, 374047.3683, 375400.828, 400701.388, 455072.7183, 477703.6083, 544074.4883, 547265.148, 576676.8783, 624121.078, 628585.0383, 641838.198, 691694.178, 735369.268, 735387.518, 737802.728, 761989.498, 761997.078, 779384.438, 787075.3583, 796218.528, 823470.7983, 829399.9183, 844592.898, 859262.588, 864007.948, 870277.0483, 874897.9883, 896406.938, 900974.9783, 943273.5183, 948274.598, 948866.768, 959802.638, 1040182.118, 1159071.248, 1167062.978, 1172278.478]
# [178358.47, 184060.14, 219277.03, 274439.83, 388354.47, 469748.77, 477682.47, 600144.56, 624111.68, 810601.42, 829407.59, 834561.92, 959800.91, 982653.19, 1160478.19, 1172287.1]
# [256991.42, 259423.351, 286920.9513, 331731.8213, 362937.58, 363012.86, 363337.9, 364475.61, 364495.21, 364938.07, 365708.68, 373749.01, 374038.58, 374383.36, 398674.49, 399268.16, 399296.66, 527298.52, 587445.95, 606352.23, 628173.59, 637647.04, 762788.14, 779382.651, 795578.711, 859274.7913, 870269.49, 877018.71, 877393.51, 896397.22, 902319.09, 943270.48, 944452.64, 962451.751, 962460.931, 978224.5511, 978897.5911, 1040190.311, 1120310.5509, 1124720.301, 1155971.671, 1156010.951, 1157929.481, 1169890.291, 1178951.591, 1186408.951, 1187897.131, 1206441.171]
# [197382.7883, 269739.8383, 407708.738, 959812.5583]
# [98172.27, 269739.67, 331736.29, 331942.01, 369167.99, 624110.87, 691694.6399, 859263.9999, 948274.45, 959802.32, 1040182.88, 1040182.9699]
# [2889.7504, 16471.2804, 38885.67, 80433.18, 98161.58, 106721.4204, 157541.9704, 161622.31, 190101.3406, 259416.67, 315940.61, 331740.45, 343389.27, 349521.2704, 362942.16, 363017.35, 363342.2, 364480.7, 372670.45, 374043.06, 374387.65, 432009.17, 432752.89, 470620.0804, 490676.91, 508154.3, 516377.57, 544075.51, 547264.51, 573763.04, 574125.13, 574821.72, 576666.5504, 593511.07, 597929.31, 601274.78, 614213.33, 628171.56, 633913.0304, 640656.28, 662804.27, 779379.86, 792016.74, 795586.86, 806742.31, 835721.55, 851403.51, 869449.3504, 870266.12, 871120.4804, 874890.81, 877397.3504, 918536.11, 918993.35, 943273.9004, 948877.79, 959813.521, 978226.7906, 1018530.811, 1027025.821, 1028893.681, 1033319.431, 1040183.73, 1060818.1604, 1077384.0704, 1097177.78, 1100987.34, 1107037.37, 1107059.68, 1113018.57, 1121764.89, 1159071.97, 1172261.0, 1178943.23]
# [3118.85, 3533.59, 4337.77, 4623.0, 5075.35, 5258.51, 5895.19, 6041.01, 6410.81, 6583.56, 6619.98, 8205.58, 8343.11, 8481.91, 8692.33, 9450.15, 9539.56, 9586.28, 9730.63, 10272.93, 10395.11, 10628.16, 10699.28, 31100.27, 55161.97, 67612.46, 67998.21, 69100.84, 69709.95, 75149.66, 78544.85, 79507.72, 79847.62, 80600.44, 92814.411, 93411.811, 93676.791, 93716.341, 98179.441, 157316.441, 160872.611, 161346.811, 177555.47, 177617.15, 178105.82, 254736.59, 259420.126, 312371.676, 331516.366, 331719.526, 331925.156, 337782.776, 337842.336, 338952.446, 339020.646, 339094.966, 339206.636, 339675.996, 339768.956, 340081.096, 341474.866, 342074.546, 342276.446, 343305.136, 343522.176, 343631.166, 347964.48, 349661.92, 362730.41, 413142.24, 415338.57, 415808.49, 461662.47, 504278.01, 504335.51, 504846.52, 505517.56, 505783.49, 506270.51, 508497.61, 515050.69, 515188.36, 515219.67, 515427.85, 517018.21, 517441.91, 517510.09, 517680.85, 518092.41, 518456.09, 518748.2, 518848.86, 519179.66, 521875.94, 522476.23, 522678.7, 522893.17, 523486.77, 523595.23, 523634.23, 523733.15, 523878.35, 525079.3, 551557.81, 587889.37, 590086.47, 590508.0, 590647.89, 590819.65, 591478.52, 594393.85, 594552.35, 594606.4, 594786.42, 595419.03, 595660.51, 595755.43, 596028.29, 596615.83, 596996.36, 597387.27, 597562.88, 597661.99, 597950.59, 598410.79, 599007.34, 599321.53, 600024.88, 600193.41, 600681.11, 601097.11, 601184.63, 601529.53, 601674.71, 605026.92, 605864.32, 606782.58, 606808.71, 607164.22, 607628.48, 608538.65, 611439.41, 611517.86, 611799.83, 611846.95, 611927.34, 613157.03, 614189.84, 648792.17, 671059.31, 681985.43, 686402.7, 686666.25, 686958.12, 687125.93, 687597.8, 688283.15, 691992.13, 706420.0, 774584.75, 774623.15, 777904.62, 779373.85, 788153.33, 795310.2, 795416.93, 827337.11, 848009.21, 863598.15, 864372.55, 864699.77, 864732.88, 864951.98, 865167.96, 865377.55, 867446.88, 867737.61, 867823.9, 867847.31, 867890.31, 868464.02, 868782.61, 869430.36, 908721.52, 944805.08, 944895.85, 945096.35, 945140.35, 945169.26, 945312.98, 945468.76, 945696.54, 946022.96, 946198.84, 946429.75, 946499.6, 946848.0, 947102.71, 948212.88, 948366.52, 948598.88, 948860.76, 949077.37, 949249.7, 950025.33, 950181.48, 950474.89, 951419.61, 951944.18, 955008.27, 955077.74, 955219.71, 955319.19, 955892.09, 956216.98, 956520.75, 956609.67, 957068.51, 959817.85, 1006508.79, 1023734.07, 1024009.94, 1024465.92, 1024889.61, 1026257.63, 1026687.37, 1026705.35, 1027063.17, 1027937.04, 1030917.52, 1031300.72, 1032807.57, 1036868.05, 1038177.54, 1038261.45, 1047482.49, 1070968.25, 1071048.74, 1071985.06, 1072558.6, 1072661.73, 1072824.53, 1074152.85, 1077939.87, 1077989.01, 1078136.24, 1078579.12, 1078679.23, 1080625.97, 1081823.18, 1089818.52, 1089956.65, 1090160.95, 1090323.04, 1090714.64, 1090792.01, 1110591.57, 1111569.3, 1111670.87, 1111970.68, 1112792.02, 1115309.6, 1117532.0, 1118334.97, 1119694.08, 1121006.47, 1123048.12, 1123089.37, 1123135.29, 1123249.83, 1123638.84, 1123762.76, 1123871.97, 1127414.47, 1128119.62, 1129636.63, 1130154.15, 1130849.62, 1131850.38, 1131983.19, 1133161.79, 1133890.43, 1134705.94, 1137755.58, 1137869.67, 1138508.29, 1138587.82, 1141316.68, 1145659.8, 1145871.18, 1150535.68, 1153533.98, 1153752.97, 1195161.43, 1195193.95, 1195308.02, 1196085.47, 1196115.49, 1196301.07, 1198034.39, 1198666.04, 1198836.4, 1198877.63, 1199101.39, 1199155.67, 1199748.35, 1199952.37, 1200053.18, 1200146.06, 1202316.94, 1203015.92, 1203404.19, 1205219.25, 1206919.09]
# [98180.835, 259419.615, 331723.285, 331929.275, 362734.915, 363021.335, 519622.145, 583879.205, 586319.445, 779377.495, 795584.915, 801245.645, 812743.615, 827343.6748, 835720.155, 864012.6248, 944455.2848, 948881.925, 951799.465, 959817.945, 1167053.405]
# [98174.3144, 362957.7544, 363015.2644, 375394.9544, 378762.7044, 591704.7144, 689947.224, 689985.534, 691690.3144, 780169.834, 787072.8844, 900979.5844, 922447.834, 941781.504, 948866.204, 954063.494, 959801.614, 1022351.124, 1029564.044]
# [98170.3967, 331734.4767, 948872.1567, 959807.5167, 959807.577]
# [375398.55, 900971.67]

# %%
keep_t = None
for sta_key in s_eqt_dict.keys():
    S_EqT_S_list = list()
    print(sta_key)
    if len(s_eqt_dict[sta_key]['S']) > 0:
        pass
    else:
        continue
    s_times = s_eqt_dict[sta_key]['S']
    s_probs = s_eqt_dict[sta_key]['S_Prob']
    prev_file = '/mnt/BYEB/LA_JAN/LA_DATA/PostProcess/SEQTRes/20100101/{}.S.txt'.format(sta_key)
    if os.path.exists(prev_file):
        f = open(prev_file,'r')
        for line in f.readlines():
            if len(line) > 3:
                s_times.append(float(line.split(' ')[0]))
                s_probs.append(0.1)
        f.close()
    
    indexs = np.argsort(s_times)
    for idx in range(len(indexs)-1):
        t_id_0 =  indexs[idx]
        t_id_1 = indexs[idx+1]
        if s_times[t_id_1] - s_times[t_id_0] < 3.0:
            if s_probs[t_id_1] >= s_probs[t_id_0]:
                keep_t = s_times[t_id_1]
                keep_prob = s_probs[t_id_1]
            else:
                keep_t = s_times[t_id_0]
                keep_prob = s_probs[t_id_0]
        elif keep_t is None:
            S_EqT_S_list.append('{:.3f} {:.5f} 0.00000000'.format(s_times[t_id_0], s_probs[t_id_0]))
        elif idx == len(indexs)-2:
            S_EqT_S_list.append('{:.3f} {:.5f}  0.00000000'.format(s_times[t_id_0], s_probs[t_id_0]))
            S_EqT_S_list.append('{:.3f} {:.5f}  0.00000000'.format(s_times[t_id_1], s_probs[t_id_1]))
        else:
            S_EqT_S_list.append('{:.3f} {:.5f}  0.00000000'.format(keep_t, keep_prob))
            keep_t = None
    cur_file = '/root/Desktop/Public/SiameseEQTransformer/notebooks/EQT2REAL_PICK_SEQT/{}.P.txt'.format(sta_key)
    f = open(cur_file,'w')
    for S_res in S_EqT_S_list:
        f.write(S_res+'\n')
    f.close()
    #print(S_EqT_S_list)
    #break

# %%
print(S_EqT_S_list)
